# %%
import os

def split_fasta_vsl2b(fasta_file, output_dir):
    """
    Podeli FASTA fajl na pojedinačne fajlove, uklanjajući zaglavlja i prazne linije između sekvenci.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    with open(fasta_file, 'r') as file:
        seq = ""
        file_count = 0
        sequences = []
        
        for line in file:
            line = line.strip()
            if line.startswith(">"):
                if seq.strip():  # Ako postoji prethodna sekvenca, dodaj je u listu
                    sequences.append(seq)
                seq = ""  # Resetuj sekvencu za novu
            else:
                seq += line
        if seq.strip():  # Dodaj poslednju sekvencu
            sequences.append(seq)

        # Generiši fajlove sa sekvencama
        total_sequences = len(sequences)
        digits = len(str(total_sequences))  # Broj cifara za formatiranje imena fajlova
        
        for i, seq in enumerate(sequences, start=1):
            if not seq.strip():  # Preskoči prazne sekvence
                print(f"Skipping empty sequence {i}")
                continue
            file_count += 1
            output_file = os.path.join(output_dir, f"seq_{i:0{digits}d}.fasta")
            with open(output_file, 'w') as out_file:
                out_file.write(seq)  # Upisuje samo sekvencu bez zaglavlja
    
    print(f"FASTA file split into {file_count} smaller files in {output_dir}.")

# %%
# Pokretanje VSL2B za svaki fajl
def run_vsl2b_on_files(output_dir):
    """
    Pokreće VSL2B za svaki pojedinačni FASTA fajl u datom direktorijumu.
    """
    results = []
    fasta_files = sorted([f for f in os.listdir(output_dir) if f.endswith('.fasta')])
    
    for i, fasta_file in enumerate(fasta_files, 1):
        file_path = os.path.join(output_dir, fasta_file)
        print(f"Processing {i}/{len(fasta_files)}: {fasta_file}")
        
        # Otvorite FASTA fajl i proverite svaku sekvencu
        with open(file_path, 'r') as file:
            header = ""
            seq = ""
            for line in file:
                line = line.strip()
                if line.startswith(">"):
                    if seq.strip():  # Ako sekvenca nije prazna
                        try:
                            check_sequence(seq)  # Proverite validnost sekvence
                        except ValueError as e:
                            print(f"Skipping {fasta_file}: {e}")
                            seq = ""  # Resetujte sekvencu
                            continue
                    header = line[1:]
                    seq = ""
                else:
                    seq += line
            # Proverite poslednju sekvencu
            if seq.strip():
                try:
                    check_sequence(seq)
                except ValueError as e:
                    print(f"Skipping {fasta_file}: {e}")
                    continue
                
        try:
            result = subprocess.run(
                ['java', '-jar', '/home/pc/Desktop/VSL2/VSL2.jar', f'-s:{file_path}'], 
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=True
            )
            if result.stderr:
                print(f"Warning: {result.stderr.strip()}")
            results.append((fasta_file, result.stdout))
        except Exception as e:
            print(f"Error processing {fasta_file}: {e}")
    
    return results

# %%
# Parsiranje izlaza iz VSL2B
def parse_vsl2b_output(vsl2b_output):
    """
    Parsira izlaz iz VSL2B programa i klasifikuje svaku poziciju u sekvenci kao 'urednu' ili 'neurednu'.
    """
    results = []
    for line in vsl2b_output.splitlines():
        line = line.strip()
        # Preskoči linije koje nisu podaci o sekvenci
        if not line or line.startswith("Prediction Scores") or line.startswith("VSL2") or line.startswith("Center"):
            continue
        parts = line.split()
        if len(parts) >= 3:
            try:
                pos = int(parts[0])  # Pozicija
                amino_acid = parts[1]  # Aminokiselina
                score = float(parts[2])  # VSL2B score
                classification = "uređena" if score <= 0.5 else "neuređena"
                results.append((pos, amino_acid, score, classification))
            except ValueError:
                # Ignoriši linije koje ne mogu da se parsiraju
                print(f"Skipping invalid line: {line}")
                continue
    return results

# %%
# Kreiranje dataframe-a
def create_dataframe_from_vsl2b_results(results):
    """
    Kreira DataFrame sa informacijama o sekvencama, uključujući pozicije,
    aminokiseline, skorove i klasifikacije.
    """
    rows = []
    for file_name, output in results:
        parsed_results = parse_vsl2b_output(output)
        for pos, amino_acid, score, classification in parsed_results:
            rows.append({
                "Ime fajla": file_name,
                "Pozicija": pos,
                "Aminokiselina": amino_acid,
                "VSL2B rezultat": score,
                "Klasifikacija": classification
            })
    return pd.DataFrame(rows)

# %%
# Glavna funkcija
def main_with_vsl2b():
    """
    Glavna funkcija za podelu FASTA fajla, pokretanje VSL2B i generisanje tabele.
    """
    fasta_file = "/home/pc/Desktop/Istrazivanje-podataka-2/Podaci/sequences_marburg.fasta"  
    output_dir = "/home/pc/Desktop/Istrazivanje-podataka-2/VSL2_parsiranje/split_sequences_vsl2b"  
    
    # Podela velikog FASTA fajla
    split_fasta_vsl2b(fasta_file, output_dir)
    
    # Pokretanje VSL2B na podeljenim fajlovima
    results = run_vsl2b_on_files(output_dir)
    
    # Kreiranje DataFrame-a
    df = create_dataframe_from_vsl2b_results(results)
    return df

# %%
# Pokretanje i čuvanje rezultata
df_results = main_with_vsl2b()

# Prikazivanje prvih 5 redova
print(df_results.head())

# Čuvanje rezultata u CSV fajl
df_results.to_csv("/home/pc/Desktop/Istrazivanje-podataka-2/VSL2_parsiranje/vsl2b_results_marburg.csv", index=False)
# Out:
# FASTA file split into 630 smaller files in /home/pc/Desktop/Istrazivanje-podataka-2/VSL2_parsiranje/split_sequences_vsl2b.
# Processing 1/630: seq_001.fasta
# Processing 2/630: seq_002.fasta
# Processing 3/630: seq_003.fasta
# Processing 4/630: seq_004.fasta
# Processing 5/630: seq_005.fasta
# Processing 6/630: seq_006.fasta
# Processing 7/630: seq_007.fasta
# Processing 8/630: seq_008.fasta
# Processing 9/630: seq_009.fasta
# Processing 10/630: seq_010.fasta
# Processing 11/630: seq_011.fasta
# Processing 12/630: seq_012.fasta
# Processing 13/630: seq_013.fasta
# Processing 14/630: seq_014.fasta
# Processing 15/630: seq_015.fasta
# Processing 16/630: seq_016.fasta
# Processing 17/630: seq_017.fasta
# Processing 18/630: seq_018.fasta
# Processing 19/630: seq_019.fasta
# Processing 20/630: seq_020.fasta
# Processing 21/630: seq_021.fasta
# Processing 22/630: seq_022.fasta
# Processing 23/630: seq_023.fasta
# Processing 24/630: seq_024.fasta
# Processing 25/630: seq_025.fasta
# Processing 26/630: seq_026.fasta
# Processing 27/630: seq_027.fasta
# Processing 28/630: seq_028.fasta
# Processing 29/630: seq_029.fasta
# Processing 30/630: seq_030.fasta
# Processing 31/630: seq_031.fasta
# Processing 32/630: seq_032.fasta
# Processing 33/630: seq_033.fasta
# Processing 34/630: seq_034.fasta
# Processing 35/630: seq_035.fasta
# Processing 36/630: seq_036.fasta
# Processing 37/630: seq_037.fasta
# Processing 38/630: seq_038.fasta
# Processing 39/630: seq_039.fasta
# Processing 40/630: seq_040.fasta
# Processing 41/630: seq_041.fasta
# Processing 42/630: seq_042.fasta
# Processing 43/630: seq_043.fasta
# Processing 44/630: seq_044.fasta
# Processing 45/630: seq_045.fasta
# Processing 46/630: seq_046.fasta
# Processing 47/630: seq_047.fasta
# Processing 48/630: seq_048.fasta
# Processing 49/630: seq_049.fasta
# Processing 50/630: seq_050.fasta
# Processing 51/630: seq_051.fasta
# Processing 52/630: seq_052.fasta
# Processing 53/630: seq_053.fasta
# Processing 54/630: seq_054.fasta
# Processing 55/630: seq_055.fasta
# Processing 56/630: seq_056.fasta
# Processing 57/630: seq_057.fasta
# Processing 58/630: seq_058.fasta
# Processing 59/630: seq_059.fasta
# Processing 60/630: seq_060.fasta
# Processing 61/630: seq_061.fasta
# Processing 62/630: seq_062.fasta
# Processing 63/630: seq_063.fasta
# Processing 64/630: seq_064.fasta
# Processing 65/630: seq_065.fasta
# Processing 66/630: seq_066.fasta
# Processing 67/630: seq_067.fasta
# Processing 68/630: seq_068.fasta
# Processing 69/630: seq_069.fasta
# Processing 70/630: seq_070.fasta
# Processing 71/630: seq_071.fasta
# Processing 72/630: seq_072.fasta
# Processing 73/630: seq_073.fasta
# Processing 74/630: seq_074.fasta
# Processing 75/630: seq_075.fasta
# Processing 76/630: seq_076.fasta
# Processing 77/630: seq_077.fasta
# Processing 78/630: seq_078.fasta
# Processing 79/630: seq_079.fasta
# Processing 80/630: seq_080.fasta
# Processing 81/630: seq_081.fasta
# Processing 82/630: seq_082.fasta
# Processing 83/630: seq_083.fasta
# Processing 84/630: seq_084.fasta
# Processing 85/630: seq_085.fasta
# Processing 86/630: seq_086.fasta
# Processing 87/630: seq_087.fasta
# Processing 88/630: seq_088.fasta
# Processing 89/630: seq_089.fasta
# Processing 90/630: seq_090.fasta
# Processing 91/630: seq_091.fasta
# Processing 92/630: seq_092.fasta
# Processing 93/630: seq_093.fasta
# Processing 94/630: seq_094.fasta
# Processing 95/630: seq_095.fasta
# Processing 96/630: seq_096.fasta
# Processing 97/630: seq_097.fasta
# Processing 98/630: seq_098.fasta
# Processing 99/630: seq_099.fasta
# Processing 100/630: seq_100.fasta
# Processing 101/630: seq_101.fasta
# Processing 102/630: seq_102.fasta
# Processing 103/630: seq_103.fasta
# Processing 104/630: seq_104.fasta
# Processing 105/630: seq_105.fasta
# Processing 106/630: seq_106.fasta
# Processing 107/630: seq_107.fasta
# Processing 108/630: seq_108.fasta
# Processing 109/630: seq_109.fasta
# Processing 110/630: seq_110.fasta
# Processing 111/630: seq_111.fasta
# Processing 112/630: seq_112.fasta
# Processing 113/630: seq_113.fasta
# Processing 114/630: seq_114.fasta
# Processing 115/630: seq_115.fasta
# Processing 116/630: seq_116.fasta
# Processing 117/630: seq_117.fasta
# Processing 118/630: seq_118.fasta
# Processing 119/630: seq_119.fasta
# Processing 120/630: seq_120.fasta
# Processing 121/630: seq_121.fasta
# Processing 122/630: seq_122.fasta
# Processing 123/630: seq_123.fasta
# Processing 124/630: seq_124.fasta
# Processing 125/630: seq_125.fasta
# Processing 126/630: seq_126.fasta
# Processing 127/630: seq_127.fasta
# Processing 128/630: seq_128.fasta
# Processing 129/630: seq_129.fasta
# Processing 130/630: seq_130.fasta
# Processing 131/630: seq_131.fasta
# Processing 132/630: seq_132.fasta
# Processing 133/630: seq_133.fasta
# Processing 134/630: seq_134.fasta
# Processing 135/630: seq_135.fasta
# Processing 136/630: seq_136.fasta
# Processing 137/630: seq_137.fasta
# Processing 138/630: seq_138.fasta
# Processing 139/630: seq_139.fasta
# Processing 140/630: seq_140.fasta
# Processing 141/630: seq_141.fasta
# Processing 142/630: seq_142.fasta
# Processing 143/630: seq_143.fasta
# Processing 144/630: seq_144.fasta
# Processing 145/630: seq_145.fasta
# Processing 146/630: seq_146.fasta
# Processing 147/630: seq_147.fasta
# Processing 148/630: seq_148.fasta
# Processing 149/630: seq_149.fasta
# Processing 150/630: seq_150.fasta
# Processing 151/630: seq_151.fasta
# Processing 152/630: seq_152.fasta
# Processing 153/630: seq_153.fasta
# Processing 154/630: seq_154.fasta
# Processing 155/630: seq_155.fasta
# Processing 156/630: seq_156.fasta
# Processing 157/630: seq_157.fasta
# Processing 158/630: seq_158.fasta
# Processing 159/630: seq_159.fasta
# Processing 160/630: seq_160.fasta
# Processing 161/630: seq_161.fasta
# Processing 162/630: seq_162.fasta
# Processing 163/630: seq_163.fasta
# Processing 164/630: seq_164.fasta
# Processing 165/630: seq_165.fasta
# Processing 166/630: seq_166.fasta
# Processing 167/630: seq_167.fasta
# Processing 168/630: seq_168.fasta
# Processing 169/630: seq_169.fasta
# Processing 170/630: seq_170.fasta
# Processing 171/630: seq_171.fasta
# Processing 172/630: seq_172.fasta
# Processing 173/630: seq_173.fasta
# Processing 174/630: seq_174.fasta
# Processing 175/630: seq_175.fasta
# Processing 176/630: seq_176.fasta
# Processing 177/630: seq_177.fasta
# Processing 178/630: seq_178.fasta
# Processing 179/630: seq_179.fasta
# Processing 180/630: seq_180.fasta
# Processing 181/630: seq_181.fasta
# Processing 182/630: seq_182.fasta
# Processing 183/630: seq_183.fasta
# Processing 184/630: seq_184.fasta
# Processing 185/630: seq_185.fasta
# Processing 186/630: seq_186.fasta
# Processing 187/630: seq_187.fasta
# Processing 188/630: seq_188.fasta
# Processing 189/630: seq_189.fasta
# Processing 190/630: seq_190.fasta
# Processing 191/630: seq_191.fasta
# Processing 192/630: seq_192.fasta
# Processing 193/630: seq_193.fasta
# Processing 194/630: seq_194.fasta
# Processing 195/630: seq_195.fasta
# Processing 196/630: seq_196.fasta
# Processing 197/630: seq_197.fasta
# Processing 198/630: seq_198.fasta
# Processing 199/630: seq_199.fasta
# Processing 200/630: seq_200.fasta
# Processing 201/630: seq_201.fasta
# Processing 202/630: seq_202.fasta
# Processing 203/630: seq_203.fasta
# Processing 204/630: seq_204.fasta
# Processing 205/630: seq_205.fasta
# Processing 206/630: seq_206.fasta
# Processing 207/630: seq_207.fasta
# Processing 208/630: seq_208.fasta
# Processing 209/630: seq_209.fasta
# Processing 210/630: seq_210.fasta
# Processing 211/630: seq_211.fasta
# Processing 212/630: seq_212.fasta
# Processing 213/630: seq_213.fasta
# Processing 214/630: seq_214.fasta
# Processing 215/630: seq_215.fasta
# Processing 216/630: seq_216.fasta
# Processing 217/630: seq_217.fasta
# Processing 218/630: seq_218.fasta
# Processing 219/630: seq_219.fasta
# Processing 220/630: seq_220.fasta
# Processing 221/630: seq_221.fasta
# Processing 222/630: seq_222.fasta
# Processing 223/630: seq_223.fasta
# Processing 224/630: seq_224.fasta
# Processing 225/630: seq_225.fasta
# Processing 226/630: seq_226.fasta
# Processing 227/630: seq_227.fasta
# Processing 228/630: seq_228.fasta
# Processing 229/630: seq_229.fasta
# Processing 230/630: seq_230.fasta
# Processing 231/630: seq_231.fasta
# Processing 232/630: seq_232.fasta
# Processing 233/630: seq_233.fasta
# Processing 234/630: seq_234.fasta
# Processing 235/630: seq_235.fasta
# Processing 236/630: seq_236.fasta
# Processing 237/630: seq_237.fasta
# Processing 238/630: seq_238.fasta
# Processing 239/630: seq_239.fasta
# Processing 240/630: seq_240.fasta
# Processing 241/630: seq_241.fasta
# Processing 242/630: seq_242.fasta
# Processing 243/630: seq_243.fasta
# Processing 244/630: seq_244.fasta
# Processing 245/630: seq_245.fasta
# Processing 246/630: seq_246.fasta
# Processing 247/630: seq_247.fasta
# Processing 248/630: seq_248.fasta
# Processing 249/630: seq_249.fasta
# Processing 250/630: seq_250.fasta
# Processing 251/630: seq_251.fasta
# Processing 252/630: seq_252.fasta
# Processing 253/630: seq_253.fasta
# Processing 254/630: seq_254.fasta
# Processing 255/630: seq_255.fasta
# Processing 256/630: seq_256.fasta
# Processing 257/630: seq_257.fasta
# Processing 258/630: seq_258.fasta
# Processing 259/630: seq_259.fasta
# Processing 260/630: seq_260.fasta
# Processing 261/630: seq_261.fasta
# Processing 262/630: seq_262.fasta
# Processing 263/630: seq_263.fasta
# Processing 264/630: seq_264.fasta
# Processing 265/630: seq_265.fasta
# Processing 266/630: seq_266.fasta
# Processing 267/630: seq_267.fasta
# Processing 268/630: seq_268.fasta
# Processing 269/630: seq_269.fasta
# Processing 270/630: seq_270.fasta
# Processing 271/630: seq_271.fasta
# Processing 272/630: seq_272.fasta
# Processing 273/630: seq_273.fasta
# Processing 274/630: seq_274.fasta
# Processing 275/630: seq_275.fasta
# Processing 276/630: seq_276.fasta
# Processing 277/630: seq_277.fasta
# Processing 278/630: seq_278.fasta
# Processing 279/630: seq_279.fasta
# Processing 280/630: seq_280.fasta
# Processing 281/630: seq_281.fasta
# Processing 282/630: seq_282.fasta
# Processing 283/630: seq_283.fasta
# Processing 284/630: seq_284.fasta
# Processing 285/630: seq_285.fasta
# Processing 286/630: seq_286.fasta
# Processing 287/630: seq_287.fasta
# Processing 288/630: seq_288.fasta
# Processing 289/630: seq_289.fasta
# Processing 290/630: seq_290.fasta
# Processing 291/630: seq_291.fasta
# Processing 292/630: seq_292.fasta
# Processing 293/630: seq_293.fasta
# Processing 294/630: seq_294.fasta
# Processing 295/630: seq_295.fasta
# Processing 296/630: seq_296.fasta
# Processing 297/630: seq_297.fasta
# Processing 298/630: seq_298.fasta
# Processing 299/630: seq_299.fasta
# Processing 300/630: seq_300.fasta
# Processing 301/630: seq_301.fasta
# Processing 302/630: seq_302.fasta
# Processing 303/630: seq_303.fasta
# Processing 304/630: seq_304.fasta
# Processing 305/630: seq_305.fasta
# Processing 306/630: seq_306.fasta
# Processing 307/630: seq_307.fasta
# Processing 308/630: seq_308.fasta
# Processing 309/630: seq_309.fasta
# Processing 310/630: seq_310.fasta
# Processing 311/630: seq_311.fasta
# Processing 312/630: seq_312.fasta
# Processing 313/630: seq_313.fasta
# Processing 314/630: seq_314.fasta
# Processing 315/630: seq_315.fasta
# Processing 316/630: seq_316.fasta
# Processing 317/630: seq_317.fasta
# Processing 318/630: seq_318.fasta
# Processing 319/630: seq_319.fasta
# Processing 320/630: seq_320.fasta
# Processing 321/630: seq_321.fasta
# Processing 322/630: seq_322.fasta
# Processing 323/630: seq_323.fasta
# Processing 324/630: seq_324.fasta
# Processing 325/630: seq_325.fasta
# Processing 326/630: seq_326.fasta
# Processing 327/630: seq_327.fasta
# Processing 328/630: seq_328.fasta
# Processing 329/630: seq_329.fasta
# Processing 330/630: seq_330.fasta
# Processing 331/630: seq_331.fasta
# Processing 332/630: seq_332.fasta
# Processing 333/630: seq_333.fasta
# Processing 334/630: seq_334.fasta
# Processing 335/630: seq_335.fasta
# Processing 336/630: seq_336.fasta
# Processing 337/630: seq_337.fasta
# Processing 338/630: seq_338.fasta
# Processing 339/630: seq_339.fasta
# Processing 340/630: seq_340.fasta
# Processing 341/630: seq_341.fasta
# Processing 342/630: seq_342.fasta
# Processing 343/630: seq_343.fasta
# Processing 344/630: seq_344.fasta
# Processing 345/630: seq_345.fasta
# Processing 346/630: seq_346.fasta
# Processing 347/630: seq_347.fasta
# Processing 348/630: seq_348.fasta
# Processing 349/630: seq_349.fasta
# Processing 350/630: seq_350.fasta
# Processing 351/630: seq_351.fasta
# Processing 352/630: seq_352.fasta
# Processing 353/630: seq_353.fasta
# Processing 354/630: seq_354.fasta
# Processing 355/630: seq_355.fasta
# Processing 356/630: seq_356.fasta
# Processing 357/630: seq_357.fasta
# Processing 358/630: seq_358.fasta
# Processing 359/630: seq_359.fasta
# Processing 360/630: seq_360.fasta
# Processing 361/630: seq_361.fasta
# Processing 362/630: seq_362.fasta
# Processing 363/630: seq_363.fasta
# Processing 364/630: seq_364.fasta
# Processing 365/630: seq_365.fasta
# Processing 366/630: seq_366.fasta
# Processing 367/630: seq_367.fasta
# Processing 368/630: seq_368.fasta
# Processing 369/630: seq_369.fasta
# Processing 370/630: seq_370.fasta
# Processing 371/630: seq_371.fasta
# Processing 372/630: seq_372.fasta
# Processing 373/630: seq_373.fasta
# Processing 374/630: seq_374.fasta
# Processing 375/630: seq_375.fasta
# Processing 376/630: seq_376.fasta
# Processing 377/630: seq_377.fasta
# Processing 378/630: seq_378.fasta
# Processing 379/630: seq_379.fasta
# Processing 380/630: seq_380.fasta
# Processing 381/630: seq_381.fasta
# Processing 382/630: seq_382.fasta
# Processing 383/630: seq_383.fasta
# Processing 384/630: seq_384.fasta
# Processing 385/630: seq_385.fasta
# Processing 386/630: seq_386.fasta
# Processing 387/630: seq_387.fasta
# Processing 388/630: seq_388.fasta
# Processing 389/630: seq_389.fasta
# Processing 390/630: seq_390.fasta
# Processing 391/630: seq_391.fasta
# Processing 392/630: seq_392.fasta
# Processing 393/630: seq_393.fasta
# Processing 394/630: seq_394.fasta
# Processing 395/630: seq_395.fasta
# Processing 396/630: seq_396.fasta
# Processing 397/630: seq_397.fasta
# Processing 398/630: seq_398.fasta
# Processing 399/630: seq_399.fasta
# Processing 400/630: seq_400.fasta
# Processing 401/630: seq_401.fasta
# Processing 402/630: seq_402.fasta
# Processing 403/630: seq_403.fasta
# Processing 404/630: seq_404.fasta
# Processing 405/630: seq_405.fasta
# Processing 406/630: seq_406.fasta
# Processing 407/630: seq_407.fasta
# Processing 408/630: seq_408.fasta
# Processing 409/630: seq_409.fasta
# Processing 410/630: seq_410.fasta
# Processing 411/630: seq_411.fasta
# Processing 412/630: seq_412.fasta
# Processing 413/630: seq_413.fasta
# Processing 414/630: seq_414.fasta
# Processing 415/630: seq_415.fasta
# Processing 416/630: seq_416.fasta
# Processing 417/630: seq_417.fasta
# Processing 418/630: seq_418.fasta
# Processing 419/630: seq_419.fasta
# Processing 420/630: seq_420.fasta
# Processing 421/630: seq_421.fasta
# Processing 422/630: seq_422.fasta
# Processing 423/630: seq_423.fasta
# Processing 424/630: seq_424.fasta
# Processing 425/630: seq_425.fasta
# Processing 426/630: seq_426.fasta
# Processing 427/630: seq_427.fasta
# Processing 428/630: seq_428.fasta
# Processing 429/630: seq_429.fasta
# Processing 430/630: seq_430.fasta
# Processing 431/630: seq_431.fasta
# Processing 432/630: seq_432.fasta
# Processing 433/630: seq_433.fasta
# Processing 434/630: seq_434.fasta
# Processing 435/630: seq_435.fasta
# Processing 436/630: seq_436.fasta
# Processing 437/630: seq_437.fasta
# Processing 438/630: seq_438.fasta
# Processing 439/630: seq_439.fasta
# Processing 440/630: seq_440.fasta
# Processing 441/630: seq_441.fasta
# Processing 442/630: seq_442.fasta
# Processing 443/630: seq_443.fasta
# Processing 444/630: seq_444.fasta
# Processing 445/630: seq_445.fasta
# Processing 446/630: seq_446.fasta
# Processing 447/630: seq_447.fasta
# Processing 448/630: seq_448.fasta
# Processing 449/630: seq_449.fasta
# Processing 450/630: seq_450.fasta
# Processing 451/630: seq_451.fasta
# Processing 452/630: seq_452.fasta
# Processing 453/630: seq_453.fasta
# Processing 454/630: seq_454.fasta
# Processing 455/630: seq_455.fasta
# Processing 456/630: seq_456.fasta
# Processing 457/630: seq_457.fasta
# Processing 458/630: seq_458.fasta
# Processing 459/630: seq_459.fasta
# Processing 460/630: seq_460.fasta
# Processing 461/630: seq_461.fasta
# Processing 462/630: seq_462.fasta
# Processing 463/630: seq_463.fasta
# Processing 464/630: seq_464.fasta
# Processing 465/630: seq_465.fasta
# Processing 466/630: seq_466.fasta
# Processing 467/630: seq_467.fasta
# Processing 468/630: seq_468.fasta
# Processing 469/630: seq_469.fasta
# Processing 470/630: seq_470.fasta
# Processing 471/630: seq_471.fasta
# Processing 472/630: seq_472.fasta
# Processing 473/630: seq_473.fasta
# Processing 474/630: seq_474.fasta
# Processing 475/630: seq_475.fasta
# Processing 476/630: seq_476.fasta
# Processing 477/630: seq_477.fasta
# Processing 478/630: seq_478.fasta
# Processing 479/630: seq_479.fasta
# Processing 480/630: seq_480.fasta
# Processing 481/630: seq_481.fasta
# Processing 482/630: seq_482.fasta
# Processing 483/630: seq_483.fasta
# Processing 484/630: seq_484.fasta
# Processing 485/630: seq_485.fasta
# Processing 486/630: seq_486.fasta
# Processing 487/630: seq_487.fasta
# Processing 488/630: seq_488.fasta
# Processing 489/630: seq_489.fasta
# Processing 490/630: seq_490.fasta
# Processing 491/630: seq_491.fasta
# Processing 492/630: seq_492.fasta
# Processing 493/630: seq_493.fasta
# Processing 494/630: seq_494.fasta
# Processing 495/630: seq_495.fasta
# Processing 496/630: seq_496.fasta
# Processing 497/630: seq_497.fasta
# Processing 498/630: seq_498.fasta
# Processing 499/630: seq_499.fasta
# Processing 500/630: seq_500.fasta
# Processing 501/630: seq_501.fasta
# Processing 502/630: seq_502.fasta
# Processing 503/630: seq_503.fasta
# Processing 504/630: seq_504.fasta
# Processing 505/630: seq_505.fasta
# Processing 506/630: seq_506.fasta
# Processing 507/630: seq_507.fasta
# Processing 508/630: seq_508.fasta
# Processing 509/630: seq_509.fasta
# Processing 510/630: seq_510.fasta
# Processing 511/630: seq_511.fasta
# Processing 512/630: seq_512.fasta
# Processing 513/630: seq_513.fasta
# Processing 514/630: seq_514.fasta
# Processing 515/630: seq_515.fasta
# Processing 516/630: seq_516.fasta
# Processing 517/630: seq_517.fasta
# Processing 518/630: seq_518.fasta
# Processing 519/630: seq_519.fasta
# Processing 520/630: seq_520.fasta
# Processing 521/630: seq_521.fasta
# Processing 522/630: seq_522.fasta
# Processing 523/630: seq_523.fasta
# Processing 524/630: seq_524.fasta
# Processing 525/630: seq_525.fasta
# Processing 526/630: seq_526.fasta
# Processing 527/630: seq_527.fasta
# Processing 528/630: seq_528.fasta
# Processing 529/630: seq_529.fasta
# Processing 530/630: seq_530.fasta
# Processing 531/630: seq_531.fasta
# Processing 532/630: seq_532.fasta
# Processing 533/630: seq_533.fasta
# Processing 534/630: seq_534.fasta
# Processing 535/630: seq_535.fasta
# Processing 536/630: seq_536.fasta
# Processing 537/630: seq_537.fasta
# Processing 538/630: seq_538.fasta
# Processing 539/630: seq_539.fasta
# Processing 540/630: seq_540.fasta
# Processing 541/630: seq_541.fasta
# Processing 542/630: seq_542.fasta
# Processing 543/630: seq_543.fasta
# Processing 544/630: seq_544.fasta
# Processing 545/630: seq_545.fasta
# Processing 546/630: seq_546.fasta
# Processing 547/630: seq_547.fasta
# Processing 548/630: seq_548.fasta
# Processing 549/630: seq_549.fasta
# Processing 550/630: seq_550.fasta
# Processing 551/630: seq_551.fasta
# Processing 552/630: seq_552.fasta
# Processing 553/630: seq_553.fasta
# Processing 554/630: seq_554.fasta
# Processing 555/630: seq_555.fasta
# Processing 556/630: seq_556.fasta
# Processing 557/630: seq_557.fasta
# Processing 558/630: seq_558.fasta
# Processing 559/630: seq_559.fasta
# Processing 560/630: seq_560.fasta
# Processing 561/630: seq_561.fasta
# Processing 562/630: seq_562.fasta
# Processing 563/630: seq_563.fasta
# Processing 564/630: seq_564.fasta
# Processing 565/630: seq_565.fasta
# Processing 566/630: seq_566.fasta
# Processing 567/630: seq_567.fasta
# Processing 568/630: seq_568.fasta
# Processing 569/630: seq_569.fasta
# Processing 570/630: seq_570.fasta
# Processing 571/630: seq_571.fasta
# Processing 572/630: seq_572.fasta
# Processing 573/630: seq_573.fasta
# Processing 574/630: seq_574.fasta
# Processing 575/630: seq_575.fasta
# Processing 576/630: seq_576.fasta
# Processing 577/630: seq_577.fasta
# Processing 578/630: seq_578.fasta
# Processing 579/630: seq_579.fasta
# Processing 580/630: seq_580.fasta
# Processing 581/630: seq_581.fasta
# Processing 582/630: seq_582.fasta
# Processing 583/630: seq_583.fasta
# Processing 584/630: seq_584.fasta
# Processing 585/630: seq_585.fasta
# Processing 586/630: seq_586.fasta
# Processing 587/630: seq_587.fasta
# Processing 588/630: seq_588.fasta
# Processing 589/630: seq_589.fasta
# Processing 590/630: seq_590.fasta
# Processing 591/630: seq_591.fasta
# Processing 592/630: seq_592.fasta
# Processing 593/630: seq_593.fasta
# Processing 594/630: seq_594.fasta
# Processing 595/630: seq_595.fasta
# Processing 596/630: seq_596.fasta
# Processing 597/630: seq_597.fasta
# Processing 598/630: seq_598.fasta
# Processing 599/630: seq_599.fasta
# Processing 600/630: seq_600.fasta
# Processing 601/630: seq_601.fasta
# Processing 602/630: seq_602.fasta
# Processing 603/630: seq_603.fasta
# Processing 604/630: seq_604.fasta
# Processing 605/630: seq_605.fasta
# Processing 606/630: seq_606.fasta
# Processing 607/630: seq_607.fasta
# Processing 608/630: seq_608.fasta
# Processing 609/630: seq_609.fasta
# Processing 610/630: seq_610.fasta
# Processing 611/630: seq_611.fasta
# Processing 612/630: seq_612.fasta
# Processing 613/630: seq_613.fasta
# Processing 614/630: seq_614.fasta
# Processing 615/630: seq_615.fasta
# Processing 616/630: seq_616.fasta
# Processing 617/630: seq_617.fasta
# Processing 618/630: seq_618.fasta
# Processing 619/630: seq_619.fasta
# Processing 620/630: seq_620.fasta
# Processing 621/630: seq_621.fasta
# Processing 622/630: seq_622.fasta
# Processing 623/630: seq_623.fasta
# Processing 624/630: seq_624.fasta
# Processing 625/630: seq_625.fasta
# Processing 626/630: seq_626.fasta
# Processing 627/630: seq_627.fasta
# Processing 628/630: seq_628.fasta
# Processing 629/630: seq_629.fasta
# Processing 630/630: seq_630.fasta
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# ...
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
#        Ime fajla  Pozicija Aminokiselina  VSL2B rezultat Klasifikacija
# 0  seq_001.fasta         1             M        0.794632     neuređena
# 1  seq_001.fasta         2             D        0.806825     neuređena
# 2  seq_001.fasta         3             L        0.758540     neuređena
# 3  seq_001.fasta         4             H        0.735277     neuređena
# 4  seq_001.fasta         5             S        0.668339     neuređena
