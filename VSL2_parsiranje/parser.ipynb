# %%
import re
import os
import subprocess 
import pandas as pd 

def izdvoji_nisku_iz_zaglavlja(zaglavlje):

    zaglavlje = zaglavlje.lstrip('>')
    match = re.match(r"^[^[]+", zaglavlje) 
    if match:
        return match.group(0).strip()  
    return zaglavlje.strip()

# %%
import os

def podeli_fasta_vsl2b(fasta_fajl, izlazni_direktorijum):
    """
    Podeli FASTA fajl na pojedinačne fajlove, uklanjajući zaglavlja za VSL2B,
    ali čuvajući zaglavlja u zasebnom CSV fajlu.

    Args:
        fasta_fajl: Putanja do ulaznog FASTA fajla.
        izlazni_direktorijum: Putanja do izlaznog direktorija.
    """

    if not os.path.exists(izlazni_direktorijum):
        os.makedirs(izlazni_direktorijum)

    # Kreiraj CSV fajl za pohranu zaglavlja
    csv_fajl = os.path.join(izlazni_direktorijum, "zaglavlja.csv")
    with open(csv_fajl, 'w') as csv:
        csv.write("Naziv_proteina\n")

    with open(fasta_fajl, 'r') as fajl:
        sekvenca = ""
        broj_fajlova = 0

        for linija in fajl:
            linija = linija.strip()
            if linija.startswith(">"):
                if sekvenca.strip():  # Ako postoji prethodna sekvenca, spremi je u fajl
                    naziv_proteina = izdvoji_nisku_iz_zaglavlja(prethodno_zaglavlje)
                    izlazni_fajl = os.path.join(izlazni_direktorijum, f"{naziv_proteina}.fasta")
                    with open(izlazni_fajl, 'w') as izlaz:
                        izlaz.write(sekvenca)  # Upisuje samo sekvencu, bez zaglavlja

                    # Upisi naziv proteina u CSV fajl
                    with open(csv_fajl, 'a') as csv:
                        csv.write(f"{naziv_proteina}\n")

                sekvenca = ""  # Resetuj sekvencu za novu
                prethodno_zaglavlje = linija  # Spremi trenutno zaglavlje
            else:
                sekvenca += linija

        # Spremi posljednju sekvencu
        if sekvenca.strip():
            naziv_proteina = izdvoji_nisku_iz_zaglavlja(prethodno_zaglavlje)
            izlazni_fajl = os.path.join(izlazni_direktorijum, f"{naziv_proteina}.fasta")
            with open(izlazni_fajl, 'w') as izlaz:
                izlaz.write(sekvenca)

            # Upisi naziv proteina u CSV fajl
            with open(csv_fajl, 'a') as csv:
                csv.write(f"{naziv_proteina}\n")

    print(f"FASTA fajl podeljen u {broj_fajlova} manjih fajlova u {izlazni_direktorijum}.")

# %%
def pokreni_vsl2b_na_fajlovima(izlazni_direktorijum):
    """
    Pokreće VSL2B za svaki pojedinačni FASTA fajl u datom direktorijumu. U prosleđivanju fajlova, preskoči zaglavlja.
    """
    rezultati = []
    fasta_fajlovi = sorted([f for f in os.listdir(izlazni_direktorijum) if f.endswith('.fasta')])
    
    for i, fasta_fajl in enumerate(fasta_fajlovi, 1):
        putanja_fajla = os.path.join(izlazni_direktorijum, fasta_fajl)
        print(f"Obradjuje se {i}/{len(fasta_fajlovi)}: {fasta_fajl}")
                
        try:
            rezultat = subprocess.run(
                ['java', '-jar', '/home/pc/Desktop/VSL2/VSL2.jar', f'-s:{putanja_fajla}'], 
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=True
            )
            if rezultat.stderr:
                print(f"Upozorenje: {rezultat.stderr.strip()}")
            rezultati.append((fasta_fajl, rezultat.stdout))
        except Exception as e:
            print(f"Greška pri obradi {fasta_fajl}: {e}")
    
    return rezultati

# %%
# Parsiranje izlaza iz VSL2B
def parse_vsl2b_output(vsl2b_output):
    """
    Parsira izlaz iz VSL2B programa i klasifikuje svaku poziciju u sekvenci kao 'uredjenu' ili 'neuredjenu'.
    """
    results = []
    for line in vsl2b_output.splitlines():
        line = line.strip()
        # Preskoči linije koje nisu podaci o sekvenci
        if not line or line.startswith("Prediction Scores") or line.startswith("VSL2") or line.startswith("Center"):
            continue
        parts = line.split()
        if len(parts) >= 3:
            try:
                pos = int(parts[0])  # Pozicija
                amino_acid = parts[1]  # Aminokiselina
                score = float(parts[2])  # VSL2B score
                classification = "uređena" if score <= 0.5 else "neuređena"
                results.append((pos, amino_acid, score, classification))
            except ValueError:
                # Ignoriši linije koje ne mogu da se parsiraju
                print(f"Skipping invalid line: {line}")
                continue
    return results

# %%
def kreiraj_dataframe_iz_rezultata(rezultati):
    """
    Kreira DataFrame sa informacijama o sekvencama, uključujući pozicije,
    aminokiseline, skorove, klasifikacije i naziv proteina.
    Sekvence se grupišu prema tipu proteina ('nucleoprotein', 'spike', 'matrix').
    """
    redovi = []
    for ime_fajla, izlaz in rezultati:
        # Izdvajanje naziva proteina iz naziva fajla (zamišljeno da naziv proteina bude u imenu fajla)
        naziv_proteina = ime_fajla.replace(".fasta", "")  # Koristi naziv fajla kao naziv proteina
        parsirani_rezultati = parse_vsl2b_output(izlaz)
        for pozicija, aminokiselina, skor, klasifikacija in parsirani_rezultati:
            redovi.append({
                "Naziv proteina": naziv_proteina.replace(".fasta", ""),
                "Pozicija": pozicija,
                "Aminokiselina": aminokiselina,
                "VSL2b rezultat": skor,
                "Klasifikacija": klasifikacija,
            })
    
    # Kreiranje DataFrame-a
    df = pd.DataFrame(redovi)
    
    # Funkcija za određivanje prioriteta grupisanja
    def prioritet_grupisanja(naziv):
        naziv = naziv.lower()
        if "nucleoprotein" in naziv or "nucleocapsid" in naziv:
            return 1
        elif "spike" in naziv:
            return 2
        elif "matrix" in naziv:
            return 3

    # Grupisanje i očuvanje redosleda unutar grupa
    df["Grupa"] = df["Naziv proteina"].apply(prioritet_grupisanja)
    df["Originalni redosled"] = range(len(df))  # Zadržavanje izvornog redosleda
    df.sort_values(by=["Grupa", "Originalni redosled"], inplace=True)
    df.drop(columns=["Grupa", "Originalni redosled"], inplace=True)  # Uklanjanje pomoćnih kolona

    return df

# %%
def glavna_funkcija_sa_podelom():
    """
    Glavna funkcija za podelu FASTA fajla, pokretanje IUPred3 i generisanje tabele.
    """
    fasta_fajl = "/home/pc/Desktop/Istrazivanje-podataka-2/Podaci/izdvojeno_proteini_ebola.fasta"
    izlazni_dir = "/home/pc/Desktop/Istrazivanje-podataka-2/VSL2_parsiranje/sekvence_ebola_2"
    
    # Podela velikog FASTA fajla
    podeli_fasta_vsl2b(fasta_fajl, izlazni_dir)
    
    # Pokretanje IUPred3 na podeljenim fajlovima
    rezultati = pokreni_vsl2b_na_fajlovima(izlazni_dir)
    
    # Kreiranje DataFrame-a
    df = kreiraj_dataframe_iz_rezultata(rezultati)
    return df

# %%
# Generisanje DataFrame-a
df_rezultati = glavna_funkcija_sa_podelom()

# Prikazivanje prvih 5 redova
print(df_rezultati.head())

# Čuvanje rezultata u CSV fajl
df_rezultati.to_csv("/home/pc/Desktop/Istrazivanje-podataka-2/VSL2_parsiranje/vsl2b_rezultati_ebola.csv", index=False)
# Out:
# FASTA fajl podeljen u 0 manjih fajlova u /home/pc/Desktop/Istrazivanje-podataka-2/VSL2_parsiranje/sekvence_ebola_2.
# Obradjuje se 1/2100: AAD14583.1 |matrix protein.fasta
# Obradjuje se 2/2100: AAD14585.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 3/2100: AAD14590.1 |nucleoprotein.fasta
# Obradjuje se 4/2100: AAG40164.1 |nucleoprotein NP.fasta
# Obradjuje se 5/2100: AAM76031.1 |nucleoprotein NP.fasta
# Obradjuje se 6/2100: AAM76033.1 |membrane-associated matrix protein VP40.fasta
# Obradjuje se 7/2100: AAN04448.1 |nucleoprotein.fasta
# Obradjuje se 8/2100: AAN04450.1 |matrix protein VP40.fasta
# Obradjuje se 9/2100: AAN37504.1 |nucleoprotein NP.fasta
# Obradjuje se 10/2100: AAN37505.1 |second nucleoprotein VP35.fasta
# Obradjuje se 11/2100: AAN37509.1 |nucleoprotein VP30.fasta
# Obradjuje se 12/2100: AAQ55045.1 |nucleoprotein.fasta
# Obradjuje se 13/2100: AAQ55047.1 |matrix protein.fasta
# Obradjuje se 14/2100: AAQ55048.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 15/2100: AAU43883.1 |major nucleoprotein.fasta
# Obradjuje se 16/2100: AAU43885.1 |matrix protein.fasta
# Obradjuje se 17/2100: AAU43888.1 |minor nucleoprotein.fasta
# Obradjuje se 18/2100: AAV48574.1 |nucleoprotein.fasta
# Obradjuje se 19/2100: AAV48576.1 |matrix protein.fasta
# Obradjuje se 20/2100: ABX75364.1 |nucleoprotein.fasta
# Obradjuje se 21/2100: ABX75366.1 |matrix protein.fasta
# Obradjuje se 22/2100: ABX75367.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 23/2100: ABY75321.1 |major nucleoprotein.fasta
# Obradjuje se 24/2100: ABY75323.1 |matrix protein.fasta
# Obradjuje se 25/2100: ABY75326.1 |minor nucleoprotein.fasta
# Obradjuje se 26/2100: ABY75327.1 |minor matrix protein.fasta
# Obradjuje se 27/2100: ACI28620.1 |nucleoprotein.fasta
# Obradjuje se 28/2100: ACI28624.1 |spike glycoprotein precursor.fasta
# Obradjuje se 29/2100: ACI28632.1 |spike glycoprotein precursor.fasta
# Obradjuje se 30/2100: ACR33187.1 |major nucleoprotein.fasta
# Obradjuje se 31/2100: ACR33189.1 |matrix protein.fasta
# Obradjuje se 32/2100: ACR33192.1 |minor nucleoprotein.fasta
# Obradjuje se 33/2100: ACT22784.1 |nucleoprotein.fasta
# Obradjuje se 34/2100: ACT22786.1 |matrix protein VP40.fasta
# Obradjuje se 35/2100: ACT22792.1 |nucleoprotein.fasta
# Obradjuje se 36/2100: ACT22799.1 |truncated matrix protein VP40.fasta
# Obradjuje se 37/2100: ACT22801.1 |matrix protein VP40.fasta
# Obradjuje se 38/2100: ACT22807.1 |nucleoprotein.fasta
# Obradjuje se 39/2100: AER59705.1 |nucleoprotein.fasta
# Obradjuje se 40/2100: AER59709.1 |second nucleoprotein.fasta
# Obradjuje se 41/2100: AER59714.1 |nucleoprotein.fasta
# Obradjuje se 42/2100: AER59715.1 |second nucleoprotein.fasta
# Obradjuje se 43/2100: AFP28224.1 |major nucleoprotein.fasta
# Obradjuje se 44/2100: AFP28226.1 |matrix protein.fasta
# Obradjuje se 45/2100: AFP28227.1 |minor nucleoprotein.fasta
# Obradjuje se 46/2100: AGB56675.1 |major nucleoprotein.fasta
# Obradjuje se 47/2100: AGB56677.1 |matrix protein.fasta
# Obradjuje se 48/2100: AGB56680.1 |minor nucleoprotein.fasta
# Obradjuje se 49/2100: AGB56686.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 50/2100: AGB56695.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 51/2100: AGB56704.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 52/2100: AGB56713.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 53/2100: AGB56722.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 54/2100: AGB56731.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 55/2100: AGB56740.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 56/2100: AGB56749.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 57/2100: AGB56758.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 58/2100: AGB56767.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 59/2100: AGB56776.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 60/2100: AGB56785.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 61/2100: AGB56794.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 62/2100: AGB56803.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 63/2100: AGB56812.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 64/2100: AGB56821.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 65/2100: AGB56830.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 66/2100: AGB56839.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 67/2100: AGC02883.1 |nucleoprotein.fasta
# Obradjuje se 68/2100: AGC02885.1 |matrix protein VP40.fasta
# Obradjuje se 69/2100: AGC02891.1 |nucleoprotein.fasta
# Obradjuje se 70/2100: AGC02893.1 |matrix protein VP40.fasta
# Obradjuje se 71/2100: AGL50925.1 |nucleoprotein.fasta
# Obradjuje se 72/2100: AGL73422.1 |nucleoprotein.fasta
# Obradjuje se 73/2100: AGL73429.1 |nucleoprotein.fasta
# Obradjuje se 74/2100: AGL73436.1 |nucleoprotein.fasta
# Obradjuje se 75/2100: AGL73443.1 |nucleoprotein.fasta
# Obradjuje se 76/2100: AGL73450.1 |nucleoprotein.fasta
# Obradjuje se 77/2100: AGL73457.1 |nucleoprotein.fasta
# Obradjuje se 78/2100: AGL73464.1 |nucleoprotein.fasta
# Obradjuje se 79/2100: AGL73471.1 |nucleoprotein.fasta
# Obradjuje se 80/2100: AHX24646.1 |nucleoprotein.fasta
# Obradjuje se 81/2100: AHX24648.1 |matrix protein.fasta
# Obradjuje se 82/2100: AHX24649.2 |virion spike glycoprotein precursor.fasta
# Obradjuje se 83/2100: AHX24655.1 |nucleoprotein.fasta
# Obradjuje se 84/2100: AHX24657.1 |matrix protein.fasta
# Obradjuje se 85/2100: AHX24658.2 |virion spike glycoprotein precursor.fasta
# Obradjuje se 86/2100: AHX24664.1 |nucleoprotein.fasta
# Obradjuje se 87/2100: AHX24666.1 |matrix protein.fasta
# Obradjuje se 88/2100: AHX24667.2 |virion spike glycoprotein precursor.fasta
# Obradjuje se 89/2100: AIE11797.1 |nucleoprotein.fasta
# Obradjuje se 90/2100: AIE11799.1 |matrix protein.fasta
# Obradjuje se 91/2100: AIE11800.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 92/2100: AIE11806.1 |nucleoprotein.fasta
# Obradjuje se 93/2100: AIE11808.1 |matrix protein.fasta
# Obradjuje se 94/2100: AIE11809.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 95/2100: AIE11815.1 |nucleoprotein.fasta
# Obradjuje se 96/2100: AIE11817.1 |matrix protein.fasta
# Obradjuje se 97/2100: AIE11818.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 98/2100: AIE11824.1 |nucleoprotein.fasta
# Obradjuje se 99/2100: AIE11826.1 |matrix protein.fasta
# Obradjuje se 100/2100: AIE11827.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 101/2100: AIE11833.1 |nucleoprotein.fasta
# Obradjuje se 102/2100: AIE11835.1 |matrix protein.fasta
# Obradjuje se 103/2100: AIE11836.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 104/2100: AIE11842.1 |nucleoprotein.fasta
# Obradjuje se 105/2100: AIE11844.1 |matrix protein.fasta
# Obradjuje se 106/2100: AIE11845.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 107/2100: AIE11851.1 |nucleoprotein.fasta
# Obradjuje se 108/2100: AIE11853.1 |matrix protein.fasta
# Obradjuje se 109/2100: AIE11854.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 110/2100: AIE11860.1 |nucleoprotein.fasta
# Obradjuje se 111/2100: AIE11862.1 |matrix protein.fasta
# Obradjuje se 112/2100: AIE11863.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 113/2100: AIE11869.1 |nucleoprotein.fasta
# Obradjuje se 114/2100: AIE11871.1 |matrix protein.fasta
# Obradjuje se 115/2100: AIE11872.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 116/2100: AIE11878.1 |nucleoprotein.fasta
# Obradjuje se 117/2100: AIE11880.1 |matrix protein.fasta
# Obradjuje se 118/2100: AIE11881.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 119/2100: AIE11887.1 |nucleoprotein.fasta
# Obradjuje se 120/2100: AIE11889.1 |matrix protein.fasta
# Obradjuje se 121/2100: AIE11890.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 122/2100: AIE11896.1 |nucleoprotein.fasta
# Obradjuje se 123/2100: AIE11898.1 |matrix protein.fasta
# Obradjuje se 124/2100: AIE11899.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 125/2100: AIE11905.1 |nucleoprotein.fasta
# Obradjuje se 126/2100: AIE11907.1 |matrix protein.fasta
# Obradjuje se 127/2100: AIE11908.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 128/2100: AIE11914.1 |nucleoprotein.fasta
# Obradjuje se 129/2100: AIE11916.1 |matrix protein.fasta
# Obradjuje se 130/2100: AIE11917.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 131/2100: AIE11925.1 |matrix protein.fasta
# Obradjuje se 132/2100: AIG95884.1 |nucleoprotein.fasta
# Obradjuje se 133/2100: AIG95885.1 |VP35 matrix protein.fasta
# Obradjuje se 134/2100: AIG95886.1 |matrix protein.fasta
# Obradjuje se 135/2100: AIG95887.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 136/2100: AIG95890.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 137/2100: AIG95893.1 |nucleoprotein.fasta
# Obradjuje se 138/2100: AIG95894.1 |VP35 matrix protein.fasta
# Obradjuje se 139/2100: AIG95895.1 |matrix protein.fasta
# Obradjuje se 140/2100: AIG95896.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 141/2100: AIG95899.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 142/2100: AIG95902.1 |nucleoprotein.fasta
# Obradjuje se 143/2100: AIG95903.1 |VP35 matrix protein.fasta
# Obradjuje se 144/2100: AIG95904.1 |matrix protein.fasta
# Obradjuje se 145/2100: AIG95905.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 146/2100: AIG95908.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 147/2100: AIG95911.1 |nucleoprotein.fasta
# Obradjuje se 148/2100: AIG95912.1 |VP35 matrix protein.fasta
# Obradjuje se 149/2100: AIG95913.1 |matrix protein.fasta
# Obradjuje se 150/2100: AIG95914.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 151/2100: AIG95917.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 152/2100: AIG95920.1 |nucleoprotein.fasta
# Obradjuje se 153/2100: AIG95921.1 |VP35 matrix protein.fasta
# Obradjuje se 154/2100: AIG95922.1 |matrix protein.fasta
# Obradjuje se 155/2100: AIG95923.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 156/2100: AIG95926.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 157/2100: AIG95929.1 |nucleoprotein.fasta
# Obradjuje se 158/2100: AIG95930.1 |VP35 matrix protein.fasta
# Obradjuje se 159/2100: AIG95931.1 |matrix protein.fasta
# Obradjuje se 160/2100: AIG95932.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 161/2100: AIG95935.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 162/2100: AIG95938.1 |nucleoprotein.fasta
# Obradjuje se 163/2100: AIG95939.1 |VP35 matrix protein.fasta
# Obradjuje se 164/2100: AIG95940.1 |matrix protein.fasta
# Obradjuje se 165/2100: AIG95941.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 166/2100: AIG95944.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 167/2100: AIG95947.1 |nucleoprotein.fasta
# Obradjuje se 168/2100: AIG95948.1 |VP35 matrix protein.fasta
# Obradjuje se 169/2100: AIG95949.1 |matrix protein.fasta
# Obradjuje se 170/2100: AIG95950.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 171/2100: AIG95953.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 172/2100: AIG95956.1 |nucleoprotein.fasta
# Obradjuje se 173/2100: AIG95957.1 |VP35 matrix protein.fasta
# Obradjuje se 174/2100: AIG95958.1 |matrix protein.fasta
# Obradjuje se 175/2100: AIG95959.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 176/2100: AIG95962.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 177/2100: AIG95965.1 |nucleoprotein.fasta
# Obradjuje se 178/2100: AIG95966.1 |VP35 matrix protein.fasta
# Obradjuje se 179/2100: AIG95967.1 |matrix protein.fasta
# Obradjuje se 180/2100: AIG95968.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 181/2100: AIG95971.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 182/2100: AIG95974.1 |nucleoprotein.fasta
# Obradjuje se 183/2100: AIG95975.1 |VP35 matrix protein.fasta
# Obradjuje se 184/2100: AIG95976.1 |matrix protein.fasta
# Obradjuje se 185/2100: AIG95977.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 186/2100: AIG95980.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 187/2100: AIG95983.1 |nucleoprotein.fasta
# Obradjuje se 188/2100: AIG95984.1 |VP35 matrix protein.fasta
# Obradjuje se 189/2100: AIG95985.1 |matrix protein.fasta
# Obradjuje se 190/2100: AIG95986.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 191/2100: AIG95989.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 192/2100: AIG95992.1 |nucleoprotein.fasta
# Obradjuje se 193/2100: AIG95993.1 |VP35 matrix protein.fasta
# Obradjuje se 194/2100: AIG95994.1 |matrix protein.fasta
# Obradjuje se 195/2100: AIG95995.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 196/2100: AIG95998.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 197/2100: AIG96001.1 |nucleoprotein.fasta
# Obradjuje se 198/2100: AIG96002.1 |VP35 matrix protein.fasta
# Obradjuje se 199/2100: AIG96003.1 |matrix protein.fasta
# Obradjuje se 200/2100: AIG96004.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 201/2100: AIG96007.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 202/2100: AIG96010.1 |nucleoprotein.fasta
# Obradjuje se 203/2100: AIG96011.1 |VP35 matrix protein.fasta
# Obradjuje se 204/2100: AIG96012.1 |matrix protein.fasta
# Obradjuje se 205/2100: AIG96013.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 206/2100: AIG96016.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 207/2100: AIG96019.1 |nucleoprotein.fasta
# Obradjuje se 208/2100: AIG96020.1 |VP35 matrix protein.fasta
# Obradjuje se 209/2100: AIG96021.1 |matrix protein.fasta
# Obradjuje se 210/2100: AIG96022.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 211/2100: AIG96025.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 212/2100: AIG96028.1 |nucleoprotein.fasta
# Obradjuje se 213/2100: AIG96029.1 |VP35 matrix protein.fasta
# Obradjuje se 214/2100: AIG96030.1 |matrix protein.fasta
# Obradjuje se 215/2100: AIG96031.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 216/2100: AIG96034.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 217/2100: AIG96037.1 |nucleoprotein.fasta
# Obradjuje se 218/2100: AIG96038.1 |VP35 matrix protein.fasta
# Obradjuje se 219/2100: AIG96039.1 |matrix protein.fasta
# Obradjuje se 220/2100: AIG96040.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 221/2100: AIG96043.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 222/2100: AIG96046.1 |nucleoprotein.fasta
# Obradjuje se 223/2100: AIG96047.1 |VP35 matrix protein.fasta
# Obradjuje se 224/2100: AIG96048.1 |matrix protein.fasta
# Obradjuje se 225/2100: AIG96049.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 226/2100: AIG96052.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 227/2100: AIG96055.1 |nucleoprotein.fasta
# Obradjuje se 228/2100: AIG96056.1 |VP35 matrix protein.fasta
# Obradjuje se 229/2100: AIG96057.1 |matrix protein.fasta
# Obradjuje se 230/2100: AIG96058.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 231/2100: AIG96061.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 232/2100: AIG96064.1 |nucleoprotein.fasta
# Obradjuje se 233/2100: AIG96065.1 |VP35 matrix protein.fasta
# Obradjuje se 234/2100: AIG96066.1 |matrix protein.fasta
# Obradjuje se 235/2100: AIG96067.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 236/2100: AIG96070.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 237/2100: AIG96073.1 |nucleoprotein.fasta
# Obradjuje se 238/2100: AIG96074.1 |VP35 matrix protein.fasta
# Obradjuje se 239/2100: AIG96075.1 |matrix protein.fasta
# Obradjuje se 240/2100: AIG96076.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 241/2100: AIG96079.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 242/2100: AIG96082.1 |nucleoprotein.fasta
# Obradjuje se 243/2100: AIG96083.1 |VP35 matrix protein.fasta
# Obradjuje se 244/2100: AIG96084.1 |matrix protein.fasta
# Obradjuje se 245/2100: AIG96085.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 246/2100: AIG96088.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 247/2100: AIG96091.1 |nucleoprotein.fasta
# Obradjuje se 248/2100: AIG96092.1 |VP35 matrix protein.fasta
# Obradjuje se 249/2100: AIG96093.1 |matrix protein.fasta
# Obradjuje se 250/2100: AIG96094.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 251/2100: AIG96097.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 252/2100: AIG96100.1 |nucleoprotein.fasta
# Obradjuje se 253/2100: AIG96101.1 |VP35 matrix protein.fasta
# Obradjuje se 254/2100: AIG96102.1 |matrix protein.fasta
# Obradjuje se 255/2100: AIG96103.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 256/2100: AIG96106.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 257/2100: AIG96109.1 |nucleoprotein.fasta
# Obradjuje se 258/2100: AIG96110.1 |VP35 matrix protein.fasta
# Obradjuje se 259/2100: AIG96111.1 |matrix protein.fasta
# Obradjuje se 260/2100: AIG96112.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 261/2100: AIG96115.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 262/2100: AIG96118.1 |nucleoprotein.fasta
# Obradjuje se 263/2100: AIG96119.1 |VP35 matrix protein.fasta
# Obradjuje se 264/2100: AIG96120.1 |matrix protein.fasta
# Obradjuje se 265/2100: AIG96121.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 266/2100: AIG96124.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 267/2100: AIG96127.1 |nucleoprotein.fasta
# Obradjuje se 268/2100: AIG96128.1 |VP35 matrix protein.fasta
# Obradjuje se 269/2100: AIG96129.1 |matrix protein.fasta
# Obradjuje se 270/2100: AIG96130.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 271/2100: AIG96133.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 272/2100: AIG96136.1 |nucleoprotein.fasta
# Obradjuje se 273/2100: AIG96137.1 |VP35 matrix protein.fasta
# Obradjuje se 274/2100: AIG96138.1 |matrix protein.fasta
# Obradjuje se 275/2100: AIG96139.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 276/2100: AIG96142.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 277/2100: AIG96145.1 |nucleoprotein.fasta
# Obradjuje se 278/2100: AIG96146.1 |VP35 matrix protein.fasta
# Obradjuje se 279/2100: AIG96147.1 |matrix protein.fasta
# Obradjuje se 280/2100: AIG96148.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 281/2100: AIG96151.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 282/2100: AIG96154.1 |nucleoprotein.fasta
# Obradjuje se 283/2100: AIG96155.1 |VP35 matrix protein.fasta
# Obradjuje se 284/2100: AIG96156.1 |matrix protein.fasta
# Obradjuje se 285/2100: AIG96157.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 286/2100: AIG96160.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 287/2100: AIG96163.1 |nucleoprotein.fasta
# Obradjuje se 288/2100: AIG96164.1 |VP35 matrix protein.fasta
# Obradjuje se 289/2100: AIG96165.1 |matrix protein.fasta
# Obradjuje se 290/2100: AIG96166.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 291/2100: AIG96169.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 292/2100: AIG96172.1 |nucleoprotein.fasta
# Obradjuje se 293/2100: AIG96173.1 |VP35 matrix protein.fasta
# Obradjuje se 294/2100: AIG96174.1 |matrix protein.fasta
# Obradjuje se 295/2100: AIG96175.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 296/2100: AIG96178.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 297/2100: AIG96181.1 |nucleoprotein.fasta
# Obradjuje se 298/2100: AIG96182.1 |VP35 matrix protein.fasta
# Obradjuje se 299/2100: AIG96183.1 |matrix protein.fasta
# Obradjuje se 300/2100: AIG96184.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 301/2100: AIG96187.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 302/2100: AIG96190.1 |nucleoprotein.fasta
# Obradjuje se 303/2100: AIG96191.1 |VP35 matrix protein.fasta
# Obradjuje se 304/2100: AIG96192.1 |matrix protein.fasta
# Obradjuje se 305/2100: AIG96193.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 306/2100: AIG96196.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 307/2100: AIG96199.1 |nucleoprotein.fasta
# Obradjuje se 308/2100: AIG96200.1 |VP35 matrix protein.fasta
# Obradjuje se 309/2100: AIG96201.1 |matrix protein.fasta
# Obradjuje se 310/2100: AIG96202.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 311/2100: AIG96205.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 312/2100: AIG96208.1 |nucleoprotein.fasta
# Obradjuje se 313/2100: AIG96209.1 |VP35 matrix protein.fasta
# Obradjuje se 314/2100: AIG96210.1 |matrix protein.fasta
# Obradjuje se 315/2100: AIG96211.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 316/2100: AIG96214.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 317/2100: AIG96217.1 |nucleoprotein.fasta
# Obradjuje se 318/2100: AIG96218.1 |VP35 matrix protein.fasta
# Obradjuje se 319/2100: AIG96219.1 |matrix protein.fasta
# Obradjuje se 320/2100: AIG96220.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 321/2100: AIG96223.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 322/2100: AIG96226.1 |nucleoprotein.fasta
# Obradjuje se 323/2100: AIG96227.1 |VP35 matrix protein.fasta
# Obradjuje se 324/2100: AIG96228.1 |matrix protein.fasta
# Obradjuje se 325/2100: AIG96229.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 326/2100: AIG96232.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 327/2100: AIG96235.1 |nucleoprotein.fasta
# Obradjuje se 328/2100: AIG96236.1 |VP35 matrix protein.fasta
# Obradjuje se 329/2100: AIG96237.1 |matrix protein.fasta
# Obradjuje se 330/2100: AIG96238.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 331/2100: AIG96241.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 332/2100: AIG96244.1 |nucleoprotein.fasta
# Obradjuje se 333/2100: AIG96245.1 |VP35 matrix protein.fasta
# Obradjuje se 334/2100: AIG96246.1 |matrix protein.fasta
# Obradjuje se 335/2100: AIG96247.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 336/2100: AIG96250.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 337/2100: AIG96253.1 |nucleoprotein.fasta
# Obradjuje se 338/2100: AIG96254.1 |VP35 matrix protein.fasta
# Obradjuje se 339/2100: AIG96255.1 |matrix protein.fasta
# Obradjuje se 340/2100: AIG96256.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 341/2100: AIG96259.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 342/2100: AIG96262.1 |nucleoprotein.fasta
# Obradjuje se 343/2100: AIG96263.1 |VP35 matrix protein.fasta
# Obradjuje se 344/2100: AIG96264.1 |matrix protein.fasta
# Obradjuje se 345/2100: AIG96265.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 346/2100: AIG96268.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 347/2100: AIG96271.1 |nucleoprotein.fasta
# Obradjuje se 348/2100: AIG96272.1 |VP35 matrix protein.fasta
# Obradjuje se 349/2100: AIG96273.1 |matrix protein.fasta
# Obradjuje se 350/2100: AIG96274.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 351/2100: AIG96277.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 352/2100: AIG96280.1 |nucleoprotein.fasta
# Obradjuje se 353/2100: AIG96281.1 |VP35 matrix protein.fasta
# Obradjuje se 354/2100: AIG96282.1 |matrix protein.fasta
# Obradjuje se 355/2100: AIG96283.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 356/2100: AIG96286.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 357/2100: AIG96289.1 |nucleoprotein.fasta
# Obradjuje se 358/2100: AIG96290.1 |VP35 matrix protein.fasta
# Obradjuje se 359/2100: AIG96291.1 |matrix protein.fasta
# Obradjuje se 360/2100: AIG96292.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 361/2100: AIG96295.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 362/2100: AIG96298.1 |nucleoprotein.fasta
# Obradjuje se 363/2100: AIG96299.1 |VP35 matrix protein.fasta
# Obradjuje se 364/2100: AIG96300.1 |matrix protein.fasta
# Obradjuje se 365/2100: AIG96301.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 366/2100: AIG96304.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 367/2100: AIG96307.1 |nucleoprotein.fasta
# Obradjuje se 368/2100: AIG96308.1 |VP35 matrix protein.fasta
# Obradjuje se 369/2100: AIG96309.1 |matrix protein.fasta
# Obradjuje se 370/2100: AIG96310.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 371/2100: AIG96313.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 372/2100: AIG96316.1 |nucleoprotein.fasta
# Obradjuje se 373/2100: AIG96317.1 |VP35 matrix protein.fasta
# Obradjuje se 374/2100: AIG96318.1 |matrix protein.fasta
# Obradjuje se 375/2100: AIG96319.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 376/2100: AIG96322.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 377/2100: AIG96325.1 |nucleoprotein.fasta
# Obradjuje se 378/2100: AIG96326.1 |VP35 matrix protein.fasta
# Obradjuje se 379/2100: AIG96327.1 |matrix protein.fasta
# Obradjuje se 380/2100: AIG96328.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 381/2100: AIG96331.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 382/2100: AIG96334.1 |nucleoprotein.fasta
# Obradjuje se 383/2100: AIG96335.1 |VP35 matrix protein.fasta
# Obradjuje se 384/2100: AIG96336.1 |matrix protein.fasta
# Obradjuje se 385/2100: AIG96337.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 386/2100: AIG96340.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 387/2100: AIG96343.1 |nucleoprotein.fasta
# Obradjuje se 388/2100: AIG96344.1 |VP35 matrix protein.fasta
# Obradjuje se 389/2100: AIG96345.1 |matrix protein.fasta
# Obradjuje se 390/2100: AIG96346.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 391/2100: AIG96349.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 392/2100: AIG96352.1 |nucleoprotein.fasta
# Obradjuje se 393/2100: AIG96353.1 |VP35 matrix protein.fasta
# Obradjuje se 394/2100: AIG96354.1 |matrix protein.fasta
# Obradjuje se 395/2100: AIG96355.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 396/2100: AIG96358.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 397/2100: AIG96361.1 |nucleoprotein.fasta
# Obradjuje se 398/2100: AIG96362.1 |VP35 matrix protein.fasta
# Obradjuje se 399/2100: AIG96363.1 |matrix protein.fasta
# Obradjuje se 400/2100: AIG96364.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 401/2100: AIG96367.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 402/2100: AIG96370.1 |nucleoprotein.fasta
# Obradjuje se 403/2100: AIG96371.1 |VP35 matrix protein.fasta
# Obradjuje se 404/2100: AIG96372.1 |matrix protein.fasta
# Obradjuje se 405/2100: AIG96373.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 406/2100: AIG96376.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 407/2100: AIG96379.1 |nucleoprotein.fasta
# Obradjuje se 408/2100: AIG96380.1 |VP35 matrix protein.fasta
# Obradjuje se 409/2100: AIG96381.1 |matrix protein.fasta
# Obradjuje se 410/2100: AIG96382.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 411/2100: AIG96385.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 412/2100: AIG96388.1 |nucleoprotein.fasta
# Obradjuje se 413/2100: AIG96389.1 |VP35 matrix protein.fasta
# Obradjuje se 414/2100: AIG96390.1 |matrix protein.fasta
# Obradjuje se 415/2100: AIG96391.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 416/2100: AIG96394.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 417/2100: AIG96397.1 |nucleoprotein.fasta
# Obradjuje se 418/2100: AIG96398.1 |VP35 matrix protein.fasta
# Obradjuje se 419/2100: AIG96399.1 |matrix protein.fasta
# Obradjuje se 420/2100: AIG96400.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 421/2100: AIG96403.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 422/2100: AIG96406.1 |nucleoprotein.fasta
# Obradjuje se 423/2100: AIG96407.1 |VP35 matrix protein.fasta
# Obradjuje se 424/2100: AIG96408.1 |matrix protein.fasta
# Obradjuje se 425/2100: AIG96409.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 426/2100: AIG96412.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 427/2100: AIG96415.1 |nucleoprotein.fasta
# Obradjuje se 428/2100: AIG96416.1 |VP35 matrix protein.fasta
# Obradjuje se 429/2100: AIG96417.1 |matrix protein.fasta
# Obradjuje se 430/2100: AIG96418.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 431/2100: AIG96421.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 432/2100: AIG96424.1 |nucleoprotein.fasta
# Obradjuje se 433/2100: AIG96425.1 |VP35 matrix protein.fasta
# Obradjuje se 434/2100: AIG96426.1 |matrix protein.fasta
# Obradjuje se 435/2100: AIG96427.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 436/2100: AIG96430.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 437/2100: AIG96433.1 |nucleoprotein.fasta
# Obradjuje se 438/2100: AIG96434.1 |VP35 matrix protein.fasta
# Obradjuje se 439/2100: AIG96435.1 |matrix protein.fasta
# Obradjuje se 440/2100: AIG96436.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 441/2100: AIG96439.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 442/2100: AIG96442.1 |nucleoprotein.fasta
# Obradjuje se 443/2100: AIG96443.1 |VP35 matrix protein.fasta
# Obradjuje se 444/2100: AIG96444.1 |matrix protein.fasta
# Obradjuje se 445/2100: AIG96445.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 446/2100: AIG96448.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 447/2100: AIG96451.1 |nucleoprotein.fasta
# Obradjuje se 448/2100: AIG96452.1 |VP35 matrix protein.fasta
# Obradjuje se 449/2100: AIG96453.1 |matrix protein.fasta
# Obradjuje se 450/2100: AIG96454.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 451/2100: AIG96457.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 452/2100: AIG96460.1 |nucleoprotein.fasta
# Obradjuje se 453/2100: AIG96461.1 |VP35 matrix protein.fasta
# Obradjuje se 454/2100: AIG96462.1 |matrix protein.fasta
# Obradjuje se 455/2100: AIG96463.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 456/2100: AIG96466.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 457/2100: AIG96469.1 |nucleoprotein.fasta
# Obradjuje se 458/2100: AIG96470.1 |VP35 matrix protein.fasta
# Obradjuje se 459/2100: AIG96471.1 |matrix protein.fasta
# Obradjuje se 460/2100: AIG96472.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 461/2100: AIG96475.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 462/2100: AIG96478.1 |nucleoprotein.fasta
# Obradjuje se 463/2100: AIG96479.1 |VP35 matrix protein.fasta
# Obradjuje se 464/2100: AIG96480.1 |matrix protein.fasta
# Obradjuje se 465/2100: AIG96481.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 466/2100: AIG96484.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 467/2100: AIG96487.1 |nucleoprotein.fasta
# Obradjuje se 468/2100: AIG96488.1 |VP35 matrix protein.fasta
# Obradjuje se 469/2100: AIG96489.1 |matrix protein.fasta
# Obradjuje se 470/2100: AIG96490.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 471/2100: AIG96493.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 472/2100: AIG96496.1 |nucleoprotein.fasta
# Obradjuje se 473/2100: AIG96497.1 |VP35 matrix protein.fasta
# Obradjuje se 474/2100: AIG96498.1 |matrix protein.fasta
# Obradjuje se 475/2100: AIG96499.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 476/2100: AIG96502.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 477/2100: AIG96505.1 |nucleoprotein.fasta
# Obradjuje se 478/2100: AIG96506.1 |VP35 matrix protein.fasta
# Obradjuje se 479/2100: AIG96507.1 |matrix protein.fasta
# Obradjuje se 480/2100: AIG96508.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 481/2100: AIG96511.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 482/2100: AIG96514.1 |nucleoprotein.fasta
# Obradjuje se 483/2100: AIG96515.1 |VP35 matrix protein.fasta
# Obradjuje se 484/2100: AIG96516.1 |matrix protein.fasta
# Obradjuje se 485/2100: AIG96517.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 486/2100: AIG96520.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 487/2100: AIG96523.1 |nucleoprotein.fasta
# Obradjuje se 488/2100: AIG96524.1 |VP35 matrix protein.fasta
# Obradjuje se 489/2100: AIG96525.1 |matrix protein.fasta
# Obradjuje se 490/2100: AIG96526.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 491/2100: AIG96529.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 492/2100: AIG96532.1 |nucleoprotein.fasta
# Obradjuje se 493/2100: AIG96533.1 |VP35 matrix protein.fasta
# Obradjuje se 494/2100: AIG96534.1 |matrix protein.fasta
# Obradjuje se 495/2100: AIG96535.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 496/2100: AIG96538.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 497/2100: AIG96541.1 |nucleoprotein.fasta
# Obradjuje se 498/2100: AIG96542.1 |VP35 matrix protein.fasta
# Obradjuje se 499/2100: AIG96543.1 |matrix protein.fasta
# Obradjuje se 500/2100: AIG96544.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 501/2100: AIG96547.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 502/2100: AIG96550.1 |nucleoprotein.fasta
# Obradjuje se 503/2100: AIG96551.1 |VP35 matrix protein.fasta
# Obradjuje se 504/2100: AIG96552.1 |matrix protein.fasta
# Obradjuje se 505/2100: AIG96553.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 506/2100: AIG96556.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 507/2100: AIG96559.1 |nucleoprotein.fasta
# Obradjuje se 508/2100: AIG96560.1 |VP35 matrix protein.fasta
# Obradjuje se 509/2100: AIG96561.1 |matrix protein.fasta
# Obradjuje se 510/2100: AIG96562.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 511/2100: AIG96565.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 512/2100: AIG96568.1 |nucleoprotein.fasta
# Obradjuje se 513/2100: AIG96569.1 |VP35 matrix protein.fasta
# Obradjuje se 514/2100: AIG96570.1 |matrix protein.fasta
# Obradjuje se 515/2100: AIG96571.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 516/2100: AIG96574.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 517/2100: AIG96577.1 |nucleoprotein.fasta
# Obradjuje se 518/2100: AIG96578.1 |VP35 matrix protein.fasta
# Obradjuje se 519/2100: AIG96579.1 |matrix protein.fasta
# Obradjuje se 520/2100: AIG96580.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 521/2100: AIG96583.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 522/2100: AIG96586.1 |nucleoprotein.fasta
# Obradjuje se 523/2100: AIG96587.1 |VP35 matrix protein.fasta
# Obradjuje se 524/2100: AIG96588.1 |matrix protein.fasta
# Obradjuje se 525/2100: AIG96589.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 526/2100: AIG96592.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 527/2100: AIG96595.1 |nucleoprotein.fasta
# Obradjuje se 528/2100: AIG96596.1 |VP35 matrix protein.fasta
# Obradjuje se 529/2100: AIG96597.1 |matrix protein.fasta
# Obradjuje se 530/2100: AIG96598.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 531/2100: AIG96601.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 532/2100: AIG96604.1 |nucleoprotein.fasta
# Obradjuje se 533/2100: AIG96605.1 |VP35 matrix protein.fasta
# Obradjuje se 534/2100: AIG96606.1 |matrix protein.fasta
# Obradjuje se 535/2100: AIG96607.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 536/2100: AIG96610.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 537/2100: AIG96613.1 |nucleoprotein.fasta
# Obradjuje se 538/2100: AIG96614.1 |VP35 matrix protein.fasta
# Obradjuje se 539/2100: AIG96615.1 |matrix protein.fasta
# Obradjuje se 540/2100: AIG96616.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 541/2100: AIG96619.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 542/2100: AIG96622.1 |nucleoprotein.fasta
# Obradjuje se 543/2100: AIG96623.1 |VP35 matrix protein.fasta
# Obradjuje se 544/2100: AIG96624.1 |matrix protein.fasta
# Obradjuje se 545/2100: AIG96625.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 546/2100: AIG96628.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 547/2100: AIG96631.1 |nucleoprotein.fasta
# Obradjuje se 548/2100: AIG96632.1 |VP35 matrix protein.fasta
# Obradjuje se 549/2100: AIG96633.1 |matrix protein.fasta
# Obradjuje se 550/2100: AIG96634.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 551/2100: AIG96637.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 552/2100: AIR94003.1 |nucleoprotein.fasta
# Obradjuje se 553/2100: AIR94005.1 |matrix protein.fasta
# Obradjuje se 554/2100: AIR94008.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 555/2100: AIR94009.1 |minor nucleoprotein.fasta
# Obradjuje se 556/2100: AIW65947.1 |nucleoprotein.fasta
# Obradjuje se 557/2100: AIW65948.1 |VP35 matrix protein.fasta
# Obradjuje se 558/2100: AIW65949.1 |matrix protein.fasta
# Obradjuje se 559/2100: AIW65950.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 560/2100: AIW65953.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 561/2100: AIY27573.1 |nucleoprotein.fasta
# Obradjuje se 562/2100: AIY27574.1 |VP35 matrix protein.fasta
# Obradjuje se 563/2100: AIY27575.1 |VP40 matrix protein.fasta
# Obradjuje se 564/2100: AIY27576.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 565/2100: AIY27579.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 566/2100: AIY29179.1 |nucleoprotein.fasta
# Obradjuje se 567/2100: AIY29180.1 |VP35 matrix protein.fasta
# Obradjuje se 568/2100: AIY29181.1 |matrix protein.fasta
# Obradjuje se 569/2100: AIY29182.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 570/2100: AIY29185.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 571/2100: AIZ50388.1 |nucleoprotein.fasta
# Obradjuje se 572/2100: AIZ50389.1 |VP35 matrix protein.fasta
# Obradjuje se 573/2100: AIZ50390.1 |matrix protein.fasta
# Obradjuje se 574/2100: AIZ50391.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 575/2100: AIZ50394.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 576/2100: AIZ50397.1 |nucleoprotein.fasta
# Obradjuje se 577/2100: AIZ50398.1 |VP35 matrix protein.fasta
# Obradjuje se 578/2100: AIZ50399.1 |matrix protein.fasta
# Obradjuje se 579/2100: AIZ50400.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 580/2100: AIZ50403.1 |truncated VP30 minor nucleoprotein.fasta
# Obradjuje se 581/2100: AIZ50406.1 |nucleoprotein.fasta
# Obradjuje se 582/2100: AIZ50407.1 |VP35 matrix protein.fasta
# Obradjuje se 583/2100: AIZ50408.1 |matrix protein.fasta
# Obradjuje se 584/2100: AIZ50409.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 585/2100: AIZ50412.1 |truncated VP30 minor nucleoprotein.fasta
# Obradjuje se 586/2100: AIZ50415.1 |nucleoprotein.fasta
# Obradjuje se 587/2100: AIZ50416.1 |VP35 matrix protein.fasta
# Obradjuje se 588/2100: AIZ50417.1 |matrix protein.fasta
# Obradjuje se 589/2100: AIZ50418.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 590/2100: AIZ50421.1 |truncated VP30 minor nucleoprotein.fasta
# Obradjuje se 591/2100: AIZ50424.1 |nucleoprotein.fasta
# Obradjuje se 592/2100: AIZ50425.1 |VP35 matrix protein.fasta
# Obradjuje se 593/2100: AIZ50426.1 |matrix protein.fasta
# Obradjuje se 594/2100: AIZ50427.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 595/2100: AIZ50430.1 |truncated VP30 minor nucleoprotein.fasta
# Obradjuje se 596/2100: AJF38892.1 |nucleoprotein.fasta
# Obradjuje se 597/2100: AJF38893.1 |VP35 matrix protein.fasta
# Obradjuje se 598/2100: AJF38894.1 |matrix protein.fasta
# Obradjuje se 599/2100: AJF38895.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 600/2100: AJG44195.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 601/2100: AKA43777.1 |nucleoprotein.fasta
# Obradjuje se 602/2100: AKA43779.1 |matrix protein.fasta
# Obradjuje se 603/2100: AKA43780.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 604/2100: AKA59357.1 |nucleoprotein.fasta
# Obradjuje se 605/2100: AKA59359.1 |matrix protein.fasta
# Obradjuje se 606/2100: AKA59363.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 607/2100: AKB09533.1 |nucleoprotein.fasta
# Obradjuje se 608/2100: AKB09535.1 |matrix protein VP40.fasta
# Obradjuje se 609/2100: AKB09539.1 |minor nucleoprotein VP30.fasta
# Obradjuje se 610/2100: AKB09542.1 |nucleoprotein.fasta
# Obradjuje se 611/2100: AKB09544.1 |matrix protein VP40.fasta
# Obradjuje se 612/2100: AKB09548.1 |minor nucleoprotein VP30.fasta
# Obradjuje se 613/2100: AKB09551.1 |nucleoprotein.fasta
# Obradjuje se 614/2100: AKB09553.1 |matrix protein VP40.fasta
# Obradjuje se 615/2100: AKB09557.1 |minor nucleoprotein VP30.fasta
# Obradjuje se 616/2100: AKB09560.1 |nucleoprotein.fasta
# Obradjuje se 617/2100: AKB09562.1 |matrix protein VP40.fasta
# Obradjuje se 618/2100: AKB09566.1 |minor nucleoprotein VP30.fasta
# Obradjuje se 619/2100: AKI82617.1 |nucleoprotein.fasta
# Obradjuje se 620/2100: AKI82625.1 |nucleoprotein.fasta
# Obradjuje se 621/2100: AKI84271.1 |nucleoprotein.fasta
# Obradjuje se 622/2100: AKI84273.1 |matrix protein VP40.fasta
# Obradjuje se 623/2100: AKI84277.1 |minor nucleoprotein VP30.fasta
# Obradjuje se 624/2100: AKT08837.1 |nucleoprotein.fasta
# Obradjuje se 625/2100: AKT08838.1 |VP35 matrix protein.fasta
# Obradjuje se 626/2100: AKT08839.1 |matrix protein.fasta
# Obradjuje se 627/2100: AKT08840.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 628/2100: AKT08843.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 629/2100: AKU75156.1 |nucleoprotein.fasta
# Obradjuje se 630/2100: AKU75159.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 631/2100: AKU75165.1 |nucleoprotein.fasta
# Obradjuje se 632/2100: AKU75168.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 633/2100: AKU75174.1 |nucleoprotein.fasta
# Obradjuje se 634/2100: AKU75177.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 635/2100: AKU75183.1 |nucleoprotein.fasta
# Obradjuje se 636/2100: AKU75186.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 637/2100: AKU75192.1 |nucleoprotein.fasta
# Obradjuje se 638/2100: AKU75195.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 639/2100: AKU75201.1 |nucleoprotein.fasta
# Obradjuje se 640/2100: AKU75204.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 641/2100: AKU75210.1 |nucleoprotein.fasta
# Obradjuje se 642/2100: AKU75213.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 643/2100: AKU75219.1 |nucleoprotein.fasta
# Obradjuje se 644/2100: AKU75222.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 645/2100: AKU75228.1 |nucleoprotein.fasta
# Obradjuje se 646/2100: AKU75231.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 647/2100: AKU75237.1 |nucleoprotein.fasta
# Obradjuje se 648/2100: AKU75240.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 649/2100: AKU75246.1 |nucleoprotein.fasta
# Obradjuje se 650/2100: AKU75249.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 651/2100: AKU75273.1 |nucleoprotein.fasta
# Obradjuje se 652/2100: AKU75276.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 653/2100: AKU75282.1 |nucleoprotein.fasta
# Obradjuje se 654/2100: AKU75285.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 655/2100: AKU75291.1 |nucleoprotein.fasta
# Obradjuje se 656/2100: AKU75294.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 657/2100: AKU75300.1 |nucleoprotein.fasta
# Obradjuje se 658/2100: AKU75303.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 659/2100: AKU75309.1 |nucleoprotein.fasta
# Obradjuje se 660/2100: AKU75312.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 661/2100: AKU75318.1 |nucleoprotein.fasta
# Obradjuje se 662/2100: AKU75321.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 663/2100: AKU75327.1 |nucleoprotein.fasta
# Obradjuje se 664/2100: AKU75330.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 665/2100: AKU75336.1 |nucleoprotein.fasta
# Obradjuje se 666/2100: AKU75339.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 667/2100: AKU75345.1 |nucleoprotein.fasta
# Obradjuje se 668/2100: AKU75350.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 669/2100: AKU75354.1 |nucleoprotein.fasta
# Obradjuje se 670/2100: AKU75357.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 671/2100: AKU75363.1 |nucleoprotein.fasta
# Obradjuje se 672/2100: AKU75366.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 673/2100: AKU75372.1 |nucleoprotein.fasta
# Obradjuje se 674/2100: AKU75375.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 675/2100: AKU75381.1 |nucleoprotein.fasta
# Obradjuje se 676/2100: AKU75384.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 677/2100: AKU75390.1 |nucleoprotein.fasta
# Obradjuje se 678/2100: AKU75393.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 679/2100: AKU75408.1 |nucleoprotein.fasta
# Obradjuje se 680/2100: AKU75411.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 681/2100: AKU75417.1 |nucleoprotein.fasta
# Obradjuje se 682/2100: AKU75420.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 683/2100: AKU75426.1 |nucleoprotein.fasta
# Obradjuje se 684/2100: AKU75429.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 685/2100: AKU75435.1 |nucleoprotein.fasta
# Obradjuje se 686/2100: AKU75438.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 687/2100: AKU75453.1 |nucleoprotein.fasta
# Obradjuje se 688/2100: AKU75456.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 689/2100: AKU75462.1 |nucleoprotein.fasta
# Obradjuje se 690/2100: AKU75465.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 691/2100: AKU75471.1 |nucleoprotein.fasta
# Obradjuje se 692/2100: AKU75474.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 693/2100: AKU75480.1 |nucleoprotein.fasta
# Obradjuje se 694/2100: AKU75483.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 695/2100: AKU75489.1 |nucleoprotein.fasta
# Obradjuje se 696/2100: AKU75492.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 697/2100: AKU75498.1 |nucleoprotein.fasta
# Obradjuje se 698/2100: AKU75501.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 699/2100: AKU75507.1 |nucleoprotein.fasta
# Obradjuje se 700/2100: AKU75510.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 701/2100: AKU75516.1 |nucleoprotein.fasta
# Obradjuje se 702/2100: AKU75519.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 703/2100: AKU75534.1 |nucleoprotein.fasta
# Obradjuje se 704/2100: AKU75537.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 705/2100: AKU75543.1 |nucleoprotein.fasta
# Obradjuje se 706/2100: AKU75546.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 707/2100: AKU75561.1 |nucleoprotein.fasta
# Obradjuje se 708/2100: AKU75564.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 709/2100: AKU75570.1 |nucleoprotein.fasta
# Obradjuje se 710/2100: AKU75573.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 711/2100: AKU75579.1 |nucleoprotein.fasta
# Obradjuje se 712/2100: AKU75582.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 713/2100: ALD19444.1 |nucleoprotein.fasta
# Obradjuje se 714/2100: ALD19446.1 |matrix protein.fasta
# Obradjuje se 715/2100: ALD19447.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 716/2100: ALF04539.1 |nucleoprotein.fasta
# Obradjuje se 717/2100: ALF04540.1 |VP35 matrix protein.fasta
# Obradjuje se 718/2100: ALF04541.1 |matrix protein.fasta
# Obradjuje se 719/2100: ALF04542.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 720/2100: ALF04545.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 721/2100: ALF04548.1 |nucleoprotein.fasta
# Obradjuje se 722/2100: ALF04549.1 |VP35 matrix protein.fasta
# Obradjuje se 723/2100: ALF04550.1 |matrix protein.fasta
# Obradjuje se 724/2100: ALF04551.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 725/2100: ALF04554.1 |VP30 minor nucleoprotein.fasta
# Obradjuje se 726/2100: ALH21183.1 |nucleoprotein.fasta
# Obradjuje se 727/2100: ALH21185.1 |matrix protein.fasta
# Obradjuje se 728/2100: ALH21186.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 729/2100: ALH21192.1 |nucleoprotein.fasta
# Obradjuje se 730/2100: ALH21194.1 |matrix protein.fasta
# Obradjuje se 731/2100: ALH21195.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 732/2100: ALH21225.1 |major nucleoprotein.fasta
# Obradjuje se 733/2100: ALH21227.1 |matrix protein.fasta
# Obradjuje se 734/2100: ALH21230.1 |minor nucleoprotein.fasta
# Obradjuje se 735/2100: ALH21451.1 |nucleoprotein.fasta
# Obradjuje se 736/2100: ALH21453.1 |matrix protein.fasta
# Obradjuje se 737/2100: ALH21454.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 738/2100: ALH21460.1 |nucleoprotein.fasta
# Obradjuje se 739/2100: ALH21462.1 |matrix protein.fasta
# Obradjuje se 740/2100: ALH21463.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 741/2100: ALL26372.1 |major nucleoprotein.fasta
# Obradjuje se 742/2100: ALL26374.1 |matrix protein.fasta
# Obradjuje se 743/2100: ALL26377.1 |minor nucleoprotein.fasta
# Obradjuje se 744/2100: ALN12276.1 |nucleoprotein.fasta
# Obradjuje se 745/2100: ALN12277.1 |VP35 matrix protein.fasta
# Obradjuje se 746/2100: ALN12278.1 |matrix protein.fasta
# Obradjuje se 747/2100: ALN12279.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 748/2100: ALN12282.1 |minor nucleoprotein.fasta
# Obradjuje se 749/2100: ALO75886.1 |nucleoprotein.fasta
# Obradjuje se 750/2100: ALO75887.1 |VP35 matrix protein.fasta
# Obradjuje se 751/2100: ALO75888.1 |matrix protein.fasta
# Obradjuje se 752/2100: ALO75889.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 753/2100: ALR82614.1 |matrix protein.fasta
# Obradjuje se 754/2100: ALR82615.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 755/2100: ALR82623.1 |matrix protein.fasta
# Obradjuje se 756/2100: ALR82624.1 |virion spike glycoprotein precursor.fasta
# Obradjuje se 757/2100: ALR82632.1 |matrix protein.fasta
# ...
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
# Skipping invalid line: Temple University, Philadelphia, PA
# Skipping invalid line: Predicted Disordered Regions:
# Skipping invalid line: NO.     RES.    PREDICTION      DISORDER
#                  Naziv proteina  Pozicija Aminokiselina  VSL2b rezultat  \
# 1002  AAD14590.1 |nucleoprotein         1             M        0.834189
# 1003  AAD14590.1 |nucleoprotein         2             D        0.793958
# 1004  AAD14590.1 |nucleoprotein         3             S        0.745936
# 1005  AAD14590.1 |nucleoprotein         4             R        0.731031
# 1006  AAD14590.1 |nucleoprotein         5             P        0.712591
#
#      Klasifikacija
# 1002     neuređena
# 1003     neuređena
# 1004     neuređena
# 1005     neuređena
# 1006     neuređena
