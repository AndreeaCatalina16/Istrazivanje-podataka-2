# %%
import os
import subprocess
import pandas as pd


def split_fasta(fasta_file, output_dir):

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    with open(fasta_file, 'r') as file:
        seq = ""
        header = ""
        file_count = 0
        sequences = []

        for line in file:
            line = line.strip()
            if line.startswith(">"):
                if seq:  # Snimi prethodnu sekvencu u listu
                    sequences.append((header, seq))
                header = line[1:]
                seq = ""
            else:
                seq += line
        if seq:  # Dodaj poslednju sekvencu
            sequences.append((header, seq))

        # Generiši fajlove sa vodećim nulama
        total_sequences = len(sequences)
        digits = len(str(total_sequences))  # Broj cifara za vodeće nule

        for i, (header, seq) in enumerate(sequences, start=1):
            file_count += 1
            output_file = os.path.join(output_dir, f"seq_{i:0{digits}d}.fasta")
            with open(output_file, 'w') as out_file:
                out_file.write(f">{header}\n{seq}\n")

    print(f"FASTA file split into {file_count} smaller files in {output_dir}.")


def run_isunstruct_on_files(output_dir):
    """
    Pokreće IsUnstruct za svaki pojedinačni FASTA fajl u datom direktorijumu.
    """
    results = []
    fasta_files = sorted([f for f in os.listdir(output_dir) if f.endswith('.fasta')])

    for i, fasta_file in enumerate(fasta_files, 1):
        file_path = os.path.join(output_dir, fasta_file)
        print(f"Processing {i}/{len(fasta_files)}: {fasta_file}")

        try:
            result = subprocess.run(
                ["/home/user/Desktop/IP2/IsUnstruct_2.02/IsUnstruct", "-use_pattern", "2", "-long_disp", "1", "-file_save", "1", file_path],
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=True
            )
            if result.stderr:
                print(f"Warning: {result.stderr.strip()}")
            results.append((fasta_file, result.stdout))
        except Exception as e:
            print(f"Error processing {fasta_file}: {e}")

    return results


def parse_isunstruct_output(isunstruct_output):
    lines = isunstruct_output.splitlines()
    results = []

    if lines[0].startswith("# IsUnstruct") and "long format" in lines[0]:
        results = parse_long_format(lines)
    elif lines[0].startswith("# IsUnstruct") and "short format" in lines[0]:
        results = parse_short_format(lines)
    else:
        raise ValueError("Nepoznat format izlaza.")

    return results
  

def create_dataframe_from_results(results):
    """
    Kreira DataFrame sa informacijama o sekvencama, uključujući pozicije,
    aminokiseline, skorove i klasifikacije.
    """
    rows = []
    for file_name, output in results:
        try:
            parsed_results = parse_isunstruct_output(output)
            print(f"Broj redova za {file_name}: {len(parsed_results)}")
            for parsed_result in parsed_results:
                rows.append({
                    "Ime fajla": file_name,
                    "Pozicija": parsed_result["Pozicija"],
                    "Aminokiselina": parsed_result["Aminokiselina"],
                    "IsUnstruct rezultat": parsed_result["Verovatnoća"],
                    "Klasifikacija": parsed_result["Klasifikacija"]
                })
        except Exception as e:
            print(f"Greška u obradi izlaza za {file_name}: {e}")

    print(f"Ukupan broj redova u DataFrame-u: {len(rows)}")
    return pd.DataFrame(rows)

def parse_long_format(lines):
    results = []
    for line in lines:
        line = line.strip()
        if line and not line.startswith("#"):  # Ignoriši komentare
            parts = line.split()
            try:
                # Ako linija sadrži tačno 4 vrednosti
                if len(parts) == 4:
                    position = int(parts[0])  # Pozicija
                    amino_acid = parts[1]  # Aminokiselina
                    state = parts[2]  # Stanje (U ili P)
                    probability = float(parts[3])  # Verovatnoća

                    classification = "neuređena" if probability > 0.5 else "uređena"
                    
                    results.append({
                        "Pozicija": position,
                        "Aminokiselina": amino_acid,
                        "Stanje": state,
                        "Verovatnoća": probability,
                        "Klasifikacija": classification
                    })
                elif len(parts) > 4:
                    position = int(parts[0])  # Pozicija
                    amino_acid = parts[1]  # Aminokiselina
                    state = parts[3]  # Stanje (U ili P)
                    probability = float(parts[4])  # Verovatnoća

                    # Ispisujemo dodatne vrednosti koje ignoriramo
                    if len(parts) > 4:
                        print(f"Ignorisano: {parts[2:]}")  # Dodaj ispis da vidiš šta je preostalo
                        
                    classification = "neuređena" if probability > 0.5 else "uređena"
                    
                    results.append({
                        "Pozicija": position,
                        "Aminokiselina": amino_acid,
                        "Stanje": state,
                        "Verovatnoća": probability,
                        "Klasifikacija": classification
                    })
                else:
                    print(f"Warning: Ignoring invalid line: {line}")
            except ValueError:
                print(f"Invalid line ignored: {line}")
    return results

def parse_short_format(lines):
    results = []
    sequence, state, probability = "", "", ""

    for line in lines:
        if line.startswith("sequence"):
            sequence = line.split()[1].replace(" ", "")  # Uklanjanje razmaka
        elif line.startswith("state"):
            state = line.split()[1].replace(" ", "")  # Uklanjanje razmaka
        elif line.startswith("probability"):
            probability = line.split()[1].replace(" ", "")  # Uklanjanje razmaka
        elif line.strip() == "":
            if sequence and state and probability:
                for j, (aa, s, prob) in enumerate(zip(sequence, state, probability)):
                    classification = "neuređena" if s == "U" else "uređena"
                    try:
                        prob_value = float(prob)
                    except ValueError:
                        prob_value = -1  # Nepoznata verovatnoća
                    results.append({
                        "Pozicija": j + 1,
                        "Aminokiselina": aa,
                        "Stanje": s,
                        "Verovatnoća": prob_value,
                        "Klasifikacija": classification
                    })
            sequence, state, probability = "", "", ""

    return results


def main_with_splitting():
    fasta_file = "/home/user/Desktop/IP2//izdvojeni_proteini_marburg.fasta"
    output_dir = "/home/user/Desktop/IP2/IsUnstruct_2.02/split_sequences_izdvojeno_marburg"

    split_fasta(fasta_file, output_dir)
    results = run_isunstruct_on_files(output_dir)
    df = create_dataframe_from_results(results)

    print(df.head(20))
    df.to_csv("/home/user/Desktop/IP2/IsUnstruct_2.02/isunstruct_izdvojeno_results.csv", index=False)
    print("Rezultati su sačuvani u CSV fajl.")


# Pokretanje glavne funkcije
main_with_splitting()
# Out:
# FASTA file split into 105 smaller files in /home/user/Desktop/IP2/IsUnstruct_2.02/split_sequences_izdvojeno_marburg.
# Processing 1/105: seq_001.fasta
# Processing 2/105: seq_002.fasta
# Processing 3/105: seq_003.fasta
# Processing 4/105: seq_004.fasta
# Processing 5/105: seq_005.fasta
# Processing 6/105: seq_006.fasta
# Processing 7/105: seq_007.fasta
# Processing 8/105: seq_008.fasta
# Processing 9/105: seq_009.fasta
# Processing 10/105: seq_010.fasta
# Processing 11/105: seq_011.fasta
# Processing 12/105: seq_012.fasta
# Processing 13/105: seq_013.fasta
# Processing 14/105: seq_014.fasta
# Processing 15/105: seq_015.fasta
# Processing 16/105: seq_016.fasta
# Processing 17/105: seq_017.fasta
# Processing 18/105: seq_018.fasta
# Processing 19/105: seq_019.fasta
# Processing 20/105: seq_020.fasta
# Processing 21/105: seq_021.fasta
# Processing 22/105: seq_022.fasta
# Processing 23/105: seq_023.fasta
# Processing 24/105: seq_024.fasta
# Processing 25/105: seq_025.fasta
# Processing 26/105: seq_026.fasta
# Processing 27/105: seq_027.fasta
# Processing 28/105: seq_028.fasta
# Processing 29/105: seq_029.fasta
# Processing 30/105: seq_030.fasta
# Processing 31/105: seq_031.fasta
# Processing 32/105: seq_032.fasta
# Processing 33/105: seq_033.fasta
# Processing 34/105: seq_034.fasta
# Processing 35/105: seq_035.fasta
# Processing 36/105: seq_036.fasta
# Processing 37/105: seq_037.fasta
# Processing 38/105: seq_038.fasta
# Processing 39/105: seq_039.fasta
# Processing 40/105: seq_040.fasta
# Processing 41/105: seq_041.fasta
# Processing 42/105: seq_042.fasta
# Processing 43/105: seq_043.fasta
# Processing 44/105: seq_044.fasta
# Processing 45/105: seq_045.fasta
# Processing 46/105: seq_046.fasta
# Processing 47/105: seq_047.fasta
# Processing 48/105: seq_048.fasta
# Processing 49/105: seq_049.fasta
# Processing 50/105: seq_050.fasta
# Processing 51/105: seq_051.fasta
# Processing 52/105: seq_052.fasta
# Processing 53/105: seq_053.fasta
# Processing 54/105: seq_054.fasta
# Processing 55/105: seq_055.fasta
# Processing 56/105: seq_056.fasta
# Processing 57/105: seq_057.fasta
# Processing 58/105: seq_058.fasta
# Processing 59/105: seq_059.fasta
# Processing 60/105: seq_060.fasta
# Processing 61/105: seq_061.fasta
# Processing 62/105: seq_062.fasta
# Processing 63/105: seq_063.fasta
# Processing 64/105: seq_064.fasta
# Processing 65/105: seq_065.fasta
# Processing 66/105: seq_066.fasta
# Processing 67/105: seq_067.fasta
# Processing 68/105: seq_068.fasta
# Processing 69/105: seq_069.fasta
# Processing 70/105: seq_070.fasta
# Processing 71/105: seq_071.fasta
# Processing 72/105: seq_072.fasta
# Processing 73/105: seq_073.fasta
# Processing 74/105: seq_074.fasta
# Processing 75/105: seq_075.fasta
# Processing 76/105: seq_076.fasta
# Processing 77/105: seq_077.fasta
# Processing 78/105: seq_078.fasta
# Processing 79/105: seq_079.fasta
# Processing 80/105: seq_080.fasta
# Processing 81/105: seq_081.fasta
# Processing 82/105: seq_082.fasta
# Processing 83/105: seq_083.fasta
# Processing 84/105: seq_084.fasta
# Processing 85/105: seq_085.fasta
# Processing 86/105: seq_086.fasta
# Processing 87/105: seq_087.fasta
# Processing 88/105: seq_088.fasta
# Processing 89/105: seq_089.fasta
# Processing 90/105: seq_090.fasta
# Processing 91/105: seq_091.fasta
# Processing 92/105: seq_092.fasta
# Processing 93/105: seq_093.fasta
# Processing 94/105: seq_094.fasta
# Processing 95/105: seq_095.fasta
# Processing 96/105: seq_096.fasta
# Processing 97/105: seq_097.fasta
# Processing 98/105: seq_098.fasta
# Processing 99/105: seq_099.fasta
# Processing 100/105: seq_100.fasta
# Processing 101/105: seq_101.fasta
# Processing 102/105: seq_102.fasta
# Processing 103/105: seq_103.fasta
# Processing 104/105: seq_104.fasta
# Processing 105/105: seq_105.fasta
# Broj redova za seq_001.fasta: 695
# Broj redova za seq_002.fasta: 303
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_003.fasta: 281
# Broj redova za seq_004.fasta: 695
# Broj redova za seq_005.fasta: 303
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_006.fasta: 281
# Broj redova za seq_007.fasta: 253
# Broj redova za seq_008.fasta: 695
# Broj redova za seq_009.fasta: 303
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_010.fasta: 281
# Broj redova za seq_011.fasta: 253
# Broj redova za seq_012.fasta: 695
# Broj redova za seq_013.fasta: 695
# Broj redova za seq_014.fasta: 303
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_015.fasta: 281
# Broj redova za seq_016.fasta: 695
# Broj redova za seq_017.fasta: 695
# Broj redova za seq_018.fasta: 695
# Broj redova za seq_019.fasta: 695
# Broj redova za seq_020.fasta: 695
# Broj redova za seq_021.fasta: 695
# Broj redova za seq_022.fasta: 695
# Broj redova za seq_023.fasta: 329
# Broj redova za seq_024.fasta: 303
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_025.fasta: 681
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_026.fasta: 281
# Broj redova za seq_027.fasta: 695
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_028.fasta: 681
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_029.fasta: 681
# Broj redova za seq_030.fasta: 695
# Broj redova za seq_031.fasta: 695
# Broj redova za seq_032.fasta: 695
# Broj redova za seq_033.fasta: 695
# Broj redova za seq_034.fasta: 303
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_035.fasta: 281
# Broj redova za seq_036.fasta: 695
# Broj redova za seq_037.fasta: 303
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_038.fasta: 281
# Broj redova za seq_039.fasta: 695
# Broj redova za seq_040.fasta: 303
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Ignorisano: ['U', 'P', '1.000']
# Broj redova za seq_041.fasta: 281
# Broj redova za seq_042.fasta: 695
# Broj redova za seq_043.fasta: 695
# Broj redova za seq_044.fasta: 695
# Broj redova za seq_045.fasta: 695
# Broj redova za seq_046.fasta: 695
# Broj redova za seq_047.fasta: 695
# Broj redova za seq_048.fasta: 695
# Broj redova za seq_049.fasta: 695
# Broj redova za seq_050.fasta: 695
# Broj redova za seq_051.fasta: 695
# Broj redova za seq_052.fasta: 695
# Broj redova za seq_053.fasta: 695
# Broj redova za seq_054.fasta: 695
# Broj redova za seq_055.fasta: 695
# Broj redova za seq_056.fasta: 695
# Broj redova za seq_057.fasta: 695
# Broj redova za seq_058.fasta: 695
# Broj redova za seq_059.fasta: 695
# Broj redova za seq_060.fasta: 695
# Broj redova za seq_061.fasta: 695
# Broj redova za seq_062.fasta: 695
# Broj redova za seq_063.fasta: 695
# Broj redova za seq_064.fasta: 695
# Broj redova za seq_065.fasta: 695
# Broj redova za seq_066.fasta: 695
# Broj redova za seq_067.fasta: 695
# Broj redova za seq_068.fasta: 695
# Broj redova za seq_069.fasta: 695
# Broj redova za seq_070.fasta: 695
# Broj redova za seq_071.fasta: 695
# Broj redova za seq_072.fasta: 695
# Broj redova za seq_073.fasta: 695
# Broj redova za seq_074.fasta: 695
# Broj redova za seq_075.fasta: 695
# Broj redova za seq_076.fasta: 695
# Broj redova za seq_077.fasta: 695
# Broj redova za seq_078.fasta: 695
# Broj redova za seq_079.fasta: 695
# Broj redova za seq_080.fasta: 695
# Broj redova za seq_081.fasta: 695
# Broj redova za seq_082.fasta: 695
# Broj redova za seq_083.fasta: 695
# Broj redova za seq_084.fasta: 695
# Broj redova za seq_085.fasta: 695
# Broj redova za seq_086.fasta: 695
# Broj redova za seq_087.fasta: 695
# Broj redova za seq_088.fasta: 695
# Broj redova za seq_089.fasta: 695
# Broj redova za seq_090.fasta: 695
# Broj redova za seq_091.fasta: 695
# Broj redova za seq_092.fasta: 695
# Broj redova za seq_093.fasta: 695
# Broj redova za seq_094.fasta: 695
# Broj redova za seq_095.fasta: 695
# Broj redova za seq_096.fasta: 695
# Broj redova za seq_097.fasta: 695
# Broj redova za seq_098.fasta: 695
# Broj redova za seq_099.fasta: 695
# Broj redova za seq_100.fasta: 695
# Broj redova za seq_101.fasta: 695
# Broj redova za seq_102.fasta: 695
# Broj redova za seq_103.fasta: 695
# Broj redova za seq_104.fasta: 695
# Broj redova za seq_105.fasta: 695
# Ukupan broj redova u DataFrame-u: 65235
#         Ime fajla  Pozicija Aminokiselina  IsUnstruct rezultat Klasifikacija
# 0   seq_001.fasta         1             M                0.974     neuređena
# 1   seq_001.fasta         2             D                0.922     neuređena
# 2   seq_001.fasta         3             L                0.847     neuređena
# 3   seq_001.fasta         4             H                0.813     neuređena
# 4   seq_001.fasta         5             S                0.779     neuređena
# 5   seq_001.fasta         6             L                0.714     neuređena
# 6   seq_001.fasta         7             L                0.686     neuređena
# 7   seq_001.fasta         8             E                0.682     neuređena
# 8   seq_001.fasta         9             L                0.663     neuređena
# 9   seq_001.fasta        10             G                0.666     neuređena
# 10  seq_001.fasta        11             T                0.666     neuređena
# 11  seq_001.fasta        12             K                0.665     neuređena
# 12  seq_001.fasta        13             P                0.655     neuređena
# 13  seq_001.fasta        14             T                0.625     neuređena
# 14  seq_001.fasta        15             A                0.594     neuređena
# 15  seq_001.fasta        16             P                0.564     neuređena
# 16  seq_001.fasta        17             H                0.504     neuređena
# 17  seq_001.fasta        18             V                0.442       uređena
# 18  seq_001.fasta        19             R                0.418       uređena
# 19  seq_001.fasta        20             N                0.383       uređena
# Rezultati su sačuvani u CSV fajl.
